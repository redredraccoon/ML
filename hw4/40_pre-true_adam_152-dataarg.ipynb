# %%
import torch
import torch.nn as nn
#from models import VGG16
import torchvision.models as models
from dataset import IMAGE_Dataset
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from pathlib import Path
import copy
import matplotlib.pyplot as plt

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
##REPRODUCIBILITY
torch.manual_seed(123)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
CUDA_DEVICES = 0
DATASET_ROOT = './new/train'
DATASET_ROOT_TEST = './new/test'

# %%
data_transform = transforms.Compose([
		transforms.RandomResizedCrop(224, interpolation=2),
		transforms.RandomHorizontalFlip(),
		transforms.ToTensor(),
		transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
	])
#print(DATASET_ROOT)
#train_load
train_set = IMAGE_Dataset(Path(DATASET_ROOT), data_transform)
train_data_loader = DataLoader(dataset=train_set, batch_size=32, shuffle=True, num_workers=1)
#test_load
test_set = IMAGE_Dataset(Path(DATASET_ROOT_TEST), data_transform)
test_data_loader = DataLoader(dataset=test_set, batch_size=32, shuffle=True, num_workers=1)

print(train_set.num_classes)
# Out:
# 196

# %%
model = models.resnet152(pretrained=True)

# %%
fc_features = model.fc.in_features
model.fc = nn.Linear(fc_features,196)

model.fc
# Out:
# Linear(in_features=2048, out_features=196, bias=True)

# %%
#model = VGG16(num_classes=train_set.num_classes)
model = model.cuda(CUDA_DEVICES)
model.train()

best_model_params = copy.deepcopy(model.state_dict())
best_acc = 0.0
num_epochs = 40
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model.parameters(), lr=0.0001)
#optimizer = torch.optim.SGD(params=model.parameters(), lr=0.001, momentum=0.9)

# %%
train_loss_list = [] 
train_acc_list = [] 
epoch_list = []

test_loss_list = [] 
test_acc_list = [] 
test_epoch_list = []

# %%
for epoch in range(num_epochs):
        print(f'Epoch: {epoch + 1}/{num_epochs}')
        print('-' * len(f'Epoch: {epoch + 1}/{num_epochs}'))

        training_loss = 0.0
        training_corrects = 0

        testing_loss = 0.0
        testing_corrects = 0

        for i, (inputs, labels) in enumerate(train_data_loader):
                inputs = Variable(inputs.cuda(CUDA_DEVICES))
                labels = Variable(labels.cuda(CUDA_DEVICES))			

                optimizer.zero_grad()

                outputs = model(inputs)
                _, preds = torch.max(outputs.data, 1)
                loss = criterion(outputs, labels)

                loss.backward()
                optimizer.step()

                training_loss += loss.item() * inputs.size(0)
                #revise loss.data[0]-->loss.item()
                training_corrects += torch.sum(preds == labels.data)
                #print(f'training_corrects: {training_corrects}')

        training_loss = training_loss / len(train_set)
        training_acc =training_corrects.double() /len(train_set)

        train_loss_list.append(training_loss)
        train_acc_list.append(training_acc)
        epoch_list.append(epoch+1)

        classes = [_dir.name for _dir in Path(DATASET_ROOT_TEST).glob('*')]
        total_correct = 0
        total = 0
        class_correct = list(0. for i in enumerate(classes))
        class_total = list(0. for i in enumerate(classes))
        with torch.no_grad():
            for inputs, labels in test_data_loader:
                    inputs = Variable(inputs.cuda(CUDA_DEVICES))
                    labels = Variable(labels.cuda(CUDA_DEVICES))
                    outputs = model(inputs)
                    _, predicted = torch.max(outputs.data, 1)
                    loss_test = criterion(outputs, labels)
                    # test
                    testing_loss += loss_test.item() * inputs.size(0)
                    testing_corrects += torch.sum(predicted == labels.data)
                    # totoal
                    total += labels.size(0)
                    total_correct += (predicted == labels).sum().item()
                    c = (predicted == labels).squeeze()
                    # batch size
                    for i in range(labels.size(0)):
                        label =labels[i]
                        class_correct[label] += c[i].item()
                        class_total[label] += 1
                
        testing_loss = testing_loss / len(test_set)
        testing_acc =testing_corrects.double() /len(test_set)

        test_loss_list.append(testing_loss)
        test_acc_list.append(testing_acc)
        test_epoch_list.append(epoch+1)


        #print(training_acc.type())
        #print(f'training_corrects: {training_corrects}\tlen(train_set):{len(train_set)}\n')
        print(f'Training loss: {training_loss:.4f}\taccuracy: {training_acc:.4f}\n')
        
        
        if training_acc > best_acc:
                best_acc = training_acc
                best_model_params = copy.deepcopy(model.state_dict())

model.load_state_dict(best_model_params)
# Out:
# Epoch: 1/40
# -----------
# Training loss: 4.3542	accuracy: 0.1292
#
# Epoch: 2/40
# -----------
# Training loss: 2.5280	accuracy: 0.4285
#
# Epoch: 3/40
# -----------
# Training loss: 1.6623	accuracy: 0.6136
#
# Epoch: 4/40
# -----------
# Training loss: 1.2679	accuracy: 0.6925
#
# Epoch: 5/40
# -----------
# Training loss: 1.0419	accuracy: 0.7386
#
# Epoch: 6/40
# -----------
# Training loss: 0.9001	accuracy: 0.7721
#
# Epoch: 7/40
# -----------
# Training loss: 0.8225	accuracy: 0.7952
#
# Epoch: 8/40
# -----------
# Training loss: 0.7492	accuracy: 0.8103
#
# Epoch: 9/40
# -----------
# Training loss: 0.7205	accuracy: 0.8136
#
# Epoch: 10/40
# ------------
# Training loss: 0.6572	accuracy: 0.8277
#
# Epoch: 11/40
# ------------
# Training loss: 0.6095	accuracy: 0.8437
#
# Epoch: 12/40
# ------------
# Training loss: 0.5695	accuracy: 0.8507
#
# Epoch: 13/40
# ------------
# Training loss: 0.5518	accuracy: 0.8576
#
# Epoch: 14/40
# ------------
# Training loss: 0.5527	accuracy: 0.8560
#
# Epoch: 15/40
# ------------
# Training loss: 0.5177	accuracy: 0.8702
#
# Epoch: 16/40
# ------------
# Training loss: 0.5263	accuracy: 0.8636
#
# Epoch: 17/40
# ------------
# Training loss: 0.4931	accuracy: 0.8701
#
# Epoch: 18/40
# ------------
# Training loss: 0.4769	accuracy: 0.8760
#
# Epoch: 19/40
# ------------
# Training loss: 0.4594	accuracy: 0.8767
#
# Epoch: 20/40
# ------------
# Training loss: 0.4550	accuracy: 0.8820
#
# Epoch: 21/40
# ------------
# Training loss: 0.4329	accuracy: 0.8849
#
# Epoch: 22/40
# ------------
# Training loss: 0.4422	accuracy: 0.8864
#
# Epoch: 23/40
# ------------
# Training loss: 0.4387	accuracy: 0.8868
#
# Epoch: 24/40
# ------------
# Training loss: 0.4399	accuracy: 0.8861
#
# Epoch: 25/40
# ------------
# Training loss: 0.4160	accuracy: 0.8867
#
# Epoch: 26/40
# ------------
# Training loss: 0.3922	accuracy: 0.8949
#
# Epoch: 27/40
# ------------
# Training loss: 0.3883	accuracy: 0.8950
#
# Epoch: 28/40
# ------------
# Training loss: 0.3658	accuracy: 0.9036
#
# Epoch: 29/40
# ------------
# Training loss: 0.3926	accuracy: 0.8958
#
# Epoch: 30/40
# ------------
# Training loss: 0.3606	accuracy: 0.9028
#
# Epoch: 31/40
# ------------
# Training loss: 0.3709	accuracy: 0.9014
#
# Epoch: 32/40
# ------------
# Training loss: 0.3886	accuracy: 0.8964
#
# Epoch: 33/40
# ------------
# Training loss: 0.3621	accuracy: 0.9014
#
# Epoch: 34/40
# ------------
# Training loss: 0.3675	accuracy: 0.9043
#
# Epoch: 35/40
# ------------
# Training loss: 0.3499	accuracy: 0.9058
#
# Epoch: 36/40
# ------------
# Training loss: 0.3522	accuracy: 0.9074
#
# Epoch: 37/40
# ------------
# Training loss: 0.3575	accuracy: 0.9028
#
# Epoch: 38/40
# ------------
# Training loss: 0.3522	accuracy: 0.9085
#
# Epoch: 39/40
# ------------
# Training loss: 0.3122	accuracy: 0.9187
#
# Epoch: 40/40
# ------------
# Training loss: 0.3399	accuracy: 0.9120

# %%
#model.load_state_dict(best_model_params)
#torch.save(model, f'without,model-{best_acc:.02f}-best_train_acc.pth')

# %%
plt.plot(epoch_list, train_loss_list, label='train')
plt.plot(test_epoch_list, test_loss_list, label='test')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend(['train','test'], loc='upper right')
plt.savefig("loss.png",dpi=250,format="png")
plt.tight_layout()
plt.show()

plt.plot(epoch_list, train_acc_list, label='train')
plt.plot(test_epoch_list, test_acc_list, label='test')
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.legend(['train','test'], loc='upper right')
plt.savefig("accuracy.png",dpi=250,format="png")
plt.tight_layout()
plt.show()

# %%
print('Accuracy on the ALL test images: %d %%'
      % (100 * total_correct / total))

for i, c in enumerate(classes):
    print('Accuracy of %5s : %2d %%' % (
    c, 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy on the ALL test images: 80 %
# Accuracy of  0149 : 92 %
# Accuracy of  0025 : 53 %
# Accuracy of  0174 : 80 %
# Accuracy of  0151 : 79 %
# Accuracy of  0132 : 83 %
# Accuracy of  0010 : 63 %
# Accuracy of  0122 : 80 %
# Accuracy of  0143 : 75 %
# Accuracy of  0026 : 82 %
# Accuracy of  0146 : 97 %
# Accuracy of  0101 : 90 %
# Accuracy of  0075 : 43 %
# Accuracy of  0121 : 88 %
# Accuracy of  0177 : 79 %
# Accuracy of  0130 : 87 %
# Accuracy of  0067 : 73 %
# Accuracy of  0175 : 73 %
# Accuracy of  0154 : 100 %
# Accuracy of  0079 : 70 %
# Accuracy of  0131 : 92 %
# Accuracy of  0059 : 50 %
# Accuracy of  0169 : 92 %
# Accuracy of  0069 : 71 %
# Accuracy of  0072 : 66 %
# Accuracy of  0128 : 74 %
# Accuracy of  0124 : 71 %
# Accuracy of  0009 : 73 %
# Accuracy of  0032 : 87 %
# Accuracy of  0063 : 90 %
# Accuracy of  0171 : 82 %
# Accuracy of  0024 : 88 %
# Accuracy of  0152 : 77 %
# Accuracy of  0189 : 90 %
# Accuracy of  0044 : 77 %
# Accuracy of  0029 : 59 %
# Accuracy of  0127 : 87 %
# Accuracy of  0136 : 95 %
# Accuracy of  0163 : 86 %
# Accuracy of  0061 : 93 %
# Accuracy of  0047 : 85 %
# Accuracy of  0097 : 64 %
# Accuracy of  0092 : 75 %
# Accuracy of  0091 : 87 %
# Accuracy of  0006 : 86 %
# Accuracy of  0065 : 82 %
# Accuracy of  0001 : 79 %
# Accuracy of  0098 : 86 %
# Accuracy of  0051 : 97 %
# Accuracy of  0156 : 79 %
# Accuracy of  0027 : 91 %
# Accuracy of  0106 : 83 %
# Accuracy of  0035 : 90 %
# Accuracy of  0003 : 79 %
# Accuracy of  0108 : 79 %
# Accuracy of  0113 : 78 %
# Accuracy of  0054 : 67 %
# Accuracy of  0062 : 64 %
# Accuracy of  0150 : 88 %
# Accuracy of  0102 : 84 %
# Accuracy of  0076 : 76 %
# Accuracy of  0167 : 70 %
# Accuracy of  0042 : 76 %
# Accuracy of  0033 : 80 %
# Accuracy of  0157 : 91 %
# Accuracy of  0145 : 81 %
# Accuracy of  0048 : 69 %
# Accuracy of  0176 : 73 %
# Accuracy of  0186 : 82 %
# Accuracy of  0135 : 72 %
# Accuracy of  0060 : 77 %
# Accuracy of  0052 : 85 %
# Accuracy of  0160 : 93 %
# Accuracy of  0195 : 76 %
# Accuracy of  0058 : 82 %
# Accuracy of  0066 : 85 %
# Accuracy of  0103 : 76 %
# Accuracy of  0181 : 92 %
# Accuracy of  0056 : 89 %
# Accuracy of  0085 : 95 %
# Accuracy of  0050 : 92 %
# Accuracy of  0158 : 86 %
# Accuracy of  0015 : 86 %
# Accuracy of  0184 : 55 %
# Accuracy of  0142 : 87 %
# Accuracy of  0119 : 82 %
# Accuracy of  0096 : 83 %
# Accuracy of  0190 : 76 %
# Accuracy of  0081 : 88 %
# Accuracy of  0088 : 69 %
# Accuracy of  0144 : 84 %
# Accuracy of  0188 : 79 %
# Accuracy of  0178 : 82 %
# Accuracy of  0087 : 84 %
# Accuracy of  0074 : 74 %
# Accuracy of  0012 : 66 %
# Accuracy of  0007 : 76 %
# Accuracy of  0161 : 93 %
# Accuracy of  0086 : 73 %
# Accuracy of  0166 : 82 %
# Accuracy of  0057 : 89 %
# Accuracy of  0173 : 72 %
# Accuracy of  0040 : 89 %
# Accuracy of  0168 : 97 %
# Accuracy of  0137 : 83 %
# Accuracy of  0070 : 90 %
# Accuracy of  0109 : 86 %
# Accuracy of  0021 : 54 %
# Accuracy of  0043 : 52 %
# Accuracy of  0034 : 63 %
# Accuracy of  0162 : 84 %
# Accuracy of  0120 : 83 %
# Accuracy of  0039 : 80 %
# Accuracy of  0104 : 69 %
# Accuracy of  0133 : 88 %
# Accuracy of  0045 : 90 %
# Accuracy of  0153 : 81 %
# Accuracy of  0002 : 71 %
# Accuracy of  0134 : 85 %
# Accuracy of  0089 : 86 %
# Accuracy of  0037 : 86 %
# Accuracy of  0183 : 78 %
# Accuracy of  0116 : 86 %
# Accuracy of  0138 : 74 %
# Accuracy of  0147 : 79 %
# Accuracy of  0019 : 45 %
# Accuracy of  0155 : 88 %
# Accuracy of  0020 : 73 %
# Accuracy of  0023 : 71 %
# Accuracy of  0068 : 80 %
# Accuracy of  0011 : 86 %
# Accuracy of  0041 : 85 %
# Accuracy of  0140 : 64 %
# Accuracy of  0141 : 91 %
# Accuracy of  0090 : 70 %
# Accuracy of  0187 : 74 %
# Accuracy of  0055 : 69 %
# Accuracy of  0105 : 90 %
# Accuracy of  0064 : 31 %
# Accuracy of  0005 : 70 %
# Accuracy of  0182 : 82 %
# Accuracy of  0172 : 93 %
# Accuracy of  0100 : 81 %
# Accuracy of  0110 : 90 %
# Accuracy of  0080 : 93 %
# Accuracy of  0094 : 90 %
# Accuracy of  0030 : 85 %
# Accuracy of  0185 : 94 %
# Accuracy of  0053 : 72 %
# Accuracy of  0114 : 84 %
# Accuracy of  0008 : 71 %
# Accuracy of  0049 : 81 %
# Accuracy of  0191 : 95 %
# Accuracy of  0111 : 95 %
# Accuracy of  0179 : 71 %
# Accuracy of  0192 : 92 %
# Accuracy of  0126 : 80 %
# Accuracy of  0038 : 60 %
# Accuracy of  0082 : 88 %
# Accuracy of  0028 : 85 %
# Accuracy of  0013 : 80 %
# Accuracy of  0194 : 84 %
# Accuracy of  0129 : 86 %
# Accuracy of  0014 : 65 %
# Accuracy of  0099 : 96 %
# Accuracy of  0115 : 84 %
# Accuracy of  0123 : 73 %
# Accuracy of  0112 : 73 %
# Accuracy of  0077 : 77 %
# Accuracy of  0084 : 88 %
# Accuracy of  0196 : 97 %
# Accuracy of  0046 : 72 %
# Accuracy of  0125 : 81 %
# Accuracy of  0018 : 45 %
# Accuracy of  0117 : 88 %
# Accuracy of  0073 : 80 %
# Accuracy of  0016 : 53 %
# Accuracy of  0164 : 95 %
# Accuracy of  0165 : 84 %
# Accuracy of  0036 : 85 %
# Accuracy of  0180 : 78 %
# Accuracy of  0031 : 40 %
# Accuracy of  0193 : 78 %
# Accuracy of  0170 : 95 %
# Accuracy of  0022 : 57 %
# Accuracy of  0118 : 97 %
# Accuracy of  0083 : 67 %
# Accuracy of  0004 : 78 %
# Accuracy of  0148 : 86 %
# Accuracy of  0095 : 80 %
# Accuracy of  0159 : 88 %
# Accuracy of  0078 : 72 %
# Accuracy of  0139 : 90 %
# Accuracy of  0107 : 84 %
# Accuracy of  0071 : 54 %
# Accuracy of  0093 : 92 %
# Accuracy of  0017 : 77 %
