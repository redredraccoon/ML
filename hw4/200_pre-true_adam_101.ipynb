# %%
import torch
import torch.nn as nn
#from models import VGG16
import torchvision.models as models
from dataset import IMAGE_Dataset
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from pathlib import Path
import copy
import matplotlib.pyplot as plt

#import os
#os.environ["CUDA_VISIBLE_DEVICES"] = "1"
##REPRODUCIBILITY
torch.manual_seed(123)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
CUDA_DEVICES = 0
DATASET_ROOT = './new/train'
DATASET_ROOT_TEST = './new/test'

# %%
data_transform = transforms.Compose([
		transforms.Resize((224,224)),
		transforms.ToTensor(),
		transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
	])
#print(DATASET_ROOT)
#train_load
train_set = IMAGE_Dataset(Path(DATASET_ROOT), data_transform)
train_data_loader = DataLoader(dataset=train_set, batch_size=64, shuffle=True, num_workers=1)
#test_load
test_set = IMAGE_Dataset(Path(DATASET_ROOT_TEST), data_transform)
test_data_loader = DataLoader(dataset=test_set, batch_size=64, shuffle=True, num_workers=1)

print(train_set.num_classes)
# Out:
# 196

# %%
model = models.resnet101(pretrained=True)

# %%
fc_features = model.fc.in_features
model.fc = nn.Linear(fc_features,196)

model.fc
# Out:
# Linear(in_features=2048, out_features=196, bias=True)

# %%
#model = VGG16(num_classes=train_set.num_classes)
model = model.cuda(CUDA_DEVICES)
model.train()

best_model_params = copy.deepcopy(model.state_dict())
best_acc = 0.0
num_epochs = 200
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model.parameters(), lr=0.0001)
#optimizer = torch.optim.SGD(params=model.parameters(), lr=0.001, momentum=0.9)

# %%
train_loss_list = [] 
train_acc_list = [] 
epoch_list = []

test_loss_list = [] 
test_acc_list = [] 
test_epoch_list = []

# %%
for epoch in range(num_epochs):
        print(f'Epoch: {epoch + 1}/{num_epochs}')
        print('-' * len(f'Epoch: {epoch + 1}/{num_epochs}'))

        training_loss = 0.0
        training_corrects = 0

        testing_loss = 0.0
        testing_corrects = 0

        for i, (inputs, labels) in enumerate(train_data_loader):
                inputs = Variable(inputs.cuda(CUDA_DEVICES))
                labels = Variable(labels.cuda(CUDA_DEVICES))			

                optimizer.zero_grad()

                outputs = model(inputs)
                _, preds = torch.max(outputs.data, 1)
                loss = criterion(outputs, labels)

                loss.backward()
                optimizer.step()

                training_loss += loss.item() * inputs.size(0)
                #revise loss.data[0]-->loss.item()
                training_corrects += torch.sum(preds == labels.data)
                #print(f'training_corrects: {training_corrects}')

        training_loss = training_loss / len(train_set)
        training_acc =training_corrects.double() /len(train_set)

        train_loss_list.append(training_loss)
        train_acc_list.append(training_acc)
        epoch_list.append(epoch+1)

        classes = [_dir.name for _dir in Path(DATASET_ROOT_TEST).glob('*')]
        total_correct = 0
        total = 0
        class_correct = list(0. for i in enumerate(classes))
        class_total = list(0. for i in enumerate(classes))
        with torch.no_grad():
            for inputs, labels in test_data_loader:
                    inputs = Variable(inputs.cuda(CUDA_DEVICES))
                    labels = Variable(labels.cuda(CUDA_DEVICES))
                    outputs = model(inputs)
                    _, predicted = torch.max(outputs.data, 1)
                    loss_test = criterion(outputs, labels)
                    # test
                    testing_loss += loss_test.item() * inputs.size(0)
                    testing_corrects += torch.sum(predicted == labels.data)
                    # totoal
                    total += labels.size(0)
                    total_correct += (predicted == labels).sum().item()
                    c = (predicted == labels).squeeze()
                    # batch size
                    for i in range(labels.size(0)):
                        label =labels[i]
                        class_correct[label] += c[i].item()
                        class_total[label] += 1
                
        testing_loss = testing_loss / len(test_set)
        testing_acc =testing_corrects.double() /len(test_set)

        test_loss_list.append(testing_loss)
        test_acc_list.append(testing_acc)
        test_epoch_list.append(epoch+1)


        #print(training_acc.type())
        #print(f'training_corrects: {training_corrects}\tlen(train_set):{len(train_set)}\n')
        print(f'Training loss: {training_loss:.4f}\taccuracy: {training_acc:.4f}\n')
        
        
        if training_acc > best_acc:
                best_acc = training_acc
                best_model_params = copy.deepcopy(model.state_dict())

model.load_state_dict(best_model_params)
# Out:
# Epoch: 1/200
# ------------
# Training loss: 4.1328	accuracy: 0.1902
#
# Epoch: 2/200
# ------------
# Training loss: 1.6276	accuracy: 0.7086
#
# Epoch: 3/200
# ------------
# Training loss: 0.5005	accuracy: 0.9207
#
# Epoch: 4/200
# ------------
# Training loss: 0.1710	accuracy: 0.9752
#
# Epoch: 5/200
# ------------
# Training loss: 0.0890	accuracy: 0.9867
#
# Epoch: 6/200
# ------------
# Training loss: 0.0417	accuracy: 0.9953
#
# Epoch: 7/200
# ------------
# Training loss: 0.0268	accuracy: 0.9969
#
# Epoch: 8/200
# ------------
# Training loss: 0.0284	accuracy: 0.9952
#
# Epoch: 9/200
# ------------
# Training loss: 0.0302	accuracy: 0.9953
#
# Epoch: 10/200
# -------------
# Training loss: 0.0462	accuracy: 0.9921
#
# Epoch: 11/200
# -------------
# Training loss: 0.1207	accuracy: 0.9791
#
# Epoch: 12/200
# -------------
# Training loss: 0.1001	accuracy: 0.9800
#
# Epoch: 13/200
# -------------
# Training loss: 0.0774	accuracy: 0.9837
#
# Epoch: 14/200
# -------------
# Training loss: 0.0323	accuracy: 0.9941
#
# Epoch: 15/200
# -------------
# Training loss: 0.0246	accuracy: 0.9957
#
# Epoch: 16/200
# -------------
# Training loss: 0.0122	accuracy: 0.9966
#
# Epoch: 17/200
# -------------
# Training loss: 0.0074	accuracy: 0.9980
#
# Epoch: 18/200
# -------------
# Training loss: 0.0068	accuracy: 0.9984
#
# Epoch: 19/200
# -------------
# Training loss: 0.0137	accuracy: 0.9964
#
# Epoch: 20/200
# -------------
# Training loss: 0.0158	accuracy: 0.9961
#
# Epoch: 21/200
# -------------
# Training loss: 0.1090	accuracy: 0.9761
#
# Epoch: 22/200
# -------------
# Training loss: 0.1200	accuracy: 0.9726
#
# Epoch: 23/200
# -------------
# Training loss: 0.0773	accuracy: 0.9832
#
# Epoch: 24/200
# -------------
# Training loss: 0.0335	accuracy: 0.9930
#
# Epoch: 25/200
# -------------
# Training loss: 0.0160	accuracy: 0.9966
#
# Epoch: 26/200
# -------------
# Training loss: 0.0112	accuracy: 0.9973
#
# Epoch: 27/200
# -------------
# Training loss: 0.0110	accuracy: 0.9967
#
# Epoch: 28/200
# -------------
# Training loss: 0.0030	accuracy: 0.9980
#
# Epoch: 102/200
# --------------
# Training loss: 0.0029	accuracy: 0.9980
#
# Epoch: 103/200
# --------------
# Training loss: 0.0029	accuracy: 0.9979
#
# Epoch: 104/200
# --------------
# Training loss: 0.0029	accuracy: 0.9977
#
# Epoch: 105/200
# --------------
# Training loss: 0.0029	accuracy: 0.9979
#
# Epoch: 106/200
# --------------
# Training loss: 0.0029	accuracy: 0.9982
#
# Epoch: 107/200
# --------------
# Training loss: 0.0027	accuracy: 0.9978
#
# Epoch: 108/200
# --------------
# Training loss: 0.0029	accuracy: 0.9982
#
# Epoch: 109/200
# --------------
# Training loss: 0.0027	accuracy: 0.9980
#
# Epoch: 110/200
# --------------
# Training loss: 0.0027	accuracy: 0.9980
#
# Epoch: 111/200
# --------------
# Training loss: 0.0028	accuracy: 0.9978
#
# Epoch: 112/200
# --------------
# Training loss: 0.0027	accuracy: 0.9982
#
# Epoch: 113/200
# --------------
# Training loss: 0.0027	accuracy: 0.9980
#
# Epoch: 114/200
# --------------
# Training loss: 0.0027	accuracy: 0.9982
#
# Epoch: 115/200
# --------------
# Training loss: 0.0032	accuracy: 0.9982
#
# Epoch: 116/200
# --------------
# Training loss: 0.0028	accuracy: 0.9980
#
# Epoch: 117/200
# --------------
# Training loss: 0.0027	accuracy: 0.9982
#
# Epoch: 118/200
# --------------
# Training loss: 0.0027	accuracy: 0.9980
#
# Epoch: 119/200
# --------------
# Training loss: 0.0027	accuracy: 0.9983
#
# Epoch: 120/200
# --------------
# Training loss: 0.0026	accuracy: 0.9983
#
# Epoch: 121/200
# --------------
# Training loss: 0.0027	accuracy: 0.9979
#
# Epoch: 122/200
# --------------
# Training loss: 0.0026	accuracy: 0.9983
#
# Epoch: 123/200
# --------------
# Training loss: 0.2295	accuracy: 0.9344
#
# Epoch: 124/200
# --------------
# Training loss: 0.0959	accuracy: 0.9727
#
# Epoch: 125/200
# --------------
# Training loss: 0.0247	accuracy: 0.9921
#
# Epoch: 126/200
# --------------
# Training loss: 0.0105	accuracy: 0.9972
#
# Epoch: 127/200
# --------------
# Training loss: 0.0042	accuracy: 0.9980
#
# Epoch: 128/200
# --------------
# Training loss: 0.0048	accuracy: 0.9978
#
# Epoch: 129/200
# --------------
# Training loss: 0.0041	accuracy: 0.9979
#
# Epoch: 130/200
# --------------
# Training loss: 0.0031	accuracy: 0.9983
#
# Epoch: 131/200
# --------------
# Training loss: 0.0030	accuracy: 0.9982
#
# Epoch: 132/200
# --------------
# Training loss: 0.0029	accuracy: 0.9979
#
# Epoch: 133/200
# --------------
# Training loss: 0.0029	accuracy: 0.9982
#
# Epoch: 134/200
# --------------
# Training loss: 0.0027	accuracy: 0.9980
#
# Epoch: 135/200
# --------------
# Training loss: 0.0027	accuracy: 0.9980
#
# Epoch: 136/200
# --------------
# Training loss: 0.0026	accuracy: 0.9983
#
# Epoch: 137/200
# --------------
# Training loss: 0.0027	accuracy: 0.9980
#
# Epoch: 138/200
# --------------
# Training loss: 0.0027	accuracy: 0.9980
#
# Epoch: 139/200
# --------------
# Training loss: 0.0027	accuracy: 0.9978
#
# Epoch: 140/200
# --------------
# Training loss: 0.0027	accuracy: 0.9977
#
# Epoch: 141/200
# --------------
# Training loss: 0.0025	accuracy: 0.9983
#
# Epoch: 142/200
# --------------
# Training loss: 0.0025	accuracy: 0.9978
#
# Epoch: 143/200
# --------------
# Training loss: 0.0026	accuracy: 0.9983
#
# Epoch: 144/200
# --------------
# Training loss: 0.0026	accuracy: 0.9977
#
# Epoch: 145/200
# --------------
# Training loss: 0.0026	accuracy: 0.9980
#
# Epoch: 146/200
# --------------
# Training loss: 0.0026	accuracy: 0.9980
#
# Epoch: 147/200
# --------------
# Training loss: 0.0026	accuracy: 0.9984
#
# Epoch: 148/200
# --------------
# Training loss: 0.0026	accuracy: 0.9979
#
# Epoch: 149/200
# --------------
# Training loss: 0.0025	accuracy: 0.9982
#
# Epoch: 150/200
# --------------
# Training loss: 0.0026	accuracy: 0.9982
#
# Epoch: 151/200
# --------------
# Training loss: 0.0024	accuracy: 0.9984
#
# Epoch: 152/200
# --------------
# Training loss: 0.0025	accuracy: 0.9980
#
# Epoch: 153/200
# --------------
# Training loss: 0.0026	accuracy: 0.9982
#
# Epoch: 154/200
# --------------
# Training loss: 0.0026	accuracy: 0.9979
#
# Epoch: 155/200
# --------------
# Training loss: 0.0026	accuracy: 0.9979
#
# Epoch: 156/200
# --------------
# Training loss: 0.0026	accuracy: 0.9979
#
# Epoch: 157/200
# --------------
# Training loss: 0.0027	accuracy: 0.9978
#
# Epoch: 158/200
# --------------
# Training loss: 0.0025	accuracy: 0.9977
#
# Epoch: 159/200
# --------------
# Training loss: 0.0025	accuracy: 0.9979
#
# Epoch: 160/200
# --------------
# Training loss: 0.0026	accuracy: 0.9980
#
# Epoch: 161/200
# --------------
# Training loss: 0.2212	accuracy: 0.9355
#
# Epoch: 162/200
# --------------
# Training loss: 0.0787	accuracy: 0.9757
#
# Epoch: 163/200
# --------------
# Training loss: 0.0183	accuracy: 0.9940
#
# Epoch: 164/200
# --------------
# Training loss: 0.0053	accuracy: 0.9977
#
# Epoch: 165/200
# --------------
# Training loss: 0.0034	accuracy: 0.9978
#
# Epoch: 166/200
# --------------
# Training loss: 0.0029	accuracy: 0.9980
#
# Epoch: 167/200
# --------------
# Training loss: 0.0029	accuracy: 0.9984
#
# Epoch: 168/200
# --------------
# Training loss: 0.0028	accuracy: 0.9983
#
# Epoch: 169/200
# --------------
# Training loss: 0.0027	accuracy: 0.9980
#
# Epoch: 170/200
# --------------
# Training loss: 0.0027	accuracy: 0.9977
#
# Epoch: 171/200
# --------------
# Training loss: 0.0026	accuracy: 0.9982
#
# Epoch: 172/200
# --------------
# Training loss: 0.0026	accuracy: 0.9978
#
# Epoch: 173/200
# --------------
# Training loss: 0.0026	accuracy: 0.9983
#
# Epoch: 174/200
# --------------
# Training loss: 0.0026	accuracy: 0.9978
#
# Epoch: 175/200
# --------------
# Training loss: 0.0027	accuracy: 0.9982
#
# Epoch: 176/200
# --------------
# Training loss: 0.0025	accuracy: 0.9980
#
# Epoch: 177/200
# --------------
# Training loss: 0.0025	accuracy: 0.9978
#
# Epoch: 178/200
# --------------
# Training loss: 0.0028	accuracy: 0.9983
#
# Epoch: 179/200
# --------------
# Training loss: 0.0058	accuracy: 0.9971
#
# Epoch: 180/200
# --------------
# Training loss: 0.1015	accuracy: 0.9695
#
# Epoch: 181/200
# --------------
# Training loss: 0.0497	accuracy: 0.9859
#
# Epoch: 182/200
# --------------
# Training loss: 0.0141	accuracy: 0.9947
#
# Epoch: 183/200
# --------------
# Training loss: 0.0042	accuracy: 0.9980
#
# Epoch: 184/200
# --------------
# Training loss: 0.0033	accuracy: 0.9974
#
# Epoch: 185/200
# --------------
# Training loss: 0.0032	accuracy: 0.9975
#
# Epoch: 186/200
# --------------
# Training loss: 0.0028	accuracy: 0.9980
#
# Epoch: 187/200
# --------------
# Training loss: 0.0026	accuracy: 0.9977
#
# Epoch: 188/200
# --------------
# Training loss: 0.0027	accuracy: 0.9978
#
# Epoch: 189/200
# --------------
# Training loss: 0.0024	accuracy: 0.9984
#
# Epoch: 190/200
# --------------
# Training loss: 0.0025	accuracy: 0.9983
#
# Epoch: 191/200
# --------------
# Training loss: 0.0025	accuracy: 0.9979
#
# Epoch: 192/200
# --------------
# Training loss: 0.0025	accuracy: 0.9982
#
# Epoch: 193/200
# --------------
# Training loss: 0.0025	accuracy: 0.9982
#
# Epoch: 194/200
# --------------
# Training loss: 0.0025	accuracy: 0.9979
#
# Epoch: 195/200
# --------------
# Training loss: 0.0025	accuracy: 0.9979
#
# Epoch: 196/200
# --------------
# Training loss: 0.0024	accuracy: 0.9980
#
# Epoch: 197/200
# --------------
# Training loss: 0.0024	accuracy: 0.9983
#
# Epoch: 198/200
# --------------
# Training loss: 0.0024	accuracy: 0.9979
#
# Epoch: 199/200
# --------------
# Training loss: 0.0025	accuracy: 0.9982
#
# Epoch: 200/200
# --------------
# Training loss: 0.0024	accuracy: 0.9978

# %%
#model.load_state_dict(best_model_params)
#torch.save(model, f'without,model-{best_acc:.02f}-best_train_acc.pth')

# %%
plt.plot(epoch_list, train_loss_list, label='train')
plt.plot(test_epoch_list, test_loss_list, label='test')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend(['train','test'], loc='upper right')
plt.savefig("loss.png",dpi=250,format="png")
plt.tight_layout()
plt.show()

plt.plot(epoch_list, train_acc_list, label='train')
plt.plot(test_epoch_list, test_acc_list, label='test')
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.legend(['train','test'], loc='upper right')
plt.savefig("accuracy.png",dpi=250,format="png")
plt.tight_layout()
plt.show()

# %%
print('Accuracy on the ALL test images: %d %%'
      % (100 * total_correct / total))

for i, c in enumerate(classes):
    print('Accuracy of %5s : %2d %%' % (
    c, 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy on the ALL test images: 87 %
# Accuracy of  0149 : 88 %
# Accuracy of  0025 : 79 %
# Accuracy of  0174 : 80 %
# Accuracy of  0151 : 79 %
# Accuracy of  0132 : 100 %
# Accuracy of  0010 : 84 %
# Accuracy of  0122 : 87 %
# Accuracy of  0143 : 97 %
# Accuracy of  0026 : 91 %
# Accuracy of  0146 : 100 %
# Accuracy of  0101 : 92 %
# Accuracy of  0075 : 56 %
# Accuracy of  0121 : 95 %
# Accuracy of  0177 : 86 %
# Accuracy of  0130 : 97 %
# Accuracy of  0067 : 84 %
# Accuracy of  0175 : 93 %
# Accuracy of  0154 : 97 %
# Accuracy of  0079 : 89 %
# Accuracy of  0131 : 85 %
# Accuracy of  0059 : 86 %
# Accuracy of  0169 : 97 %
# Accuracy of  0069 : 76 %
# Accuracy of  0072 : 88 %
# Accuracy of  0128 : 84 %
# Accuracy of  0124 : 89 %
# Accuracy of  0009 : 80 %
# Accuracy of  0032 : 97 %
# Accuracy of  0063 : 95 %
# Accuracy of  0171 : 97 %
# Accuracy of  0024 : 91 %
# Accuracy of  0152 : 82 %
# Accuracy of  0189 : 97 %
# Accuracy of  0044 : 90 %
# Accuracy of  0029 : 83 %
# Accuracy of  0127 : 85 %
# Accuracy of  0136 : 75 %
# Accuracy of  0163 : 97 %
# Accuracy of  0061 : 93 %
# Accuracy of  0047 : 91 %
# Accuracy of  0097 : 80 %
# Accuracy of  0092 : 92 %
# Accuracy of  0091 : 94 %
# Accuracy of  0006 : 88 %
# Accuracy of  0065 : 84 %
# Accuracy of  0001 : 93 %
# Accuracy of  0098 : 91 %
# Accuracy of  0051 : 100 %
# Accuracy of  0156 : 94 %
# Accuracy of  0027 : 91 %
# Accuracy of  0106 : 97 %
# Accuracy of  0035 : 90 %
# Accuracy of  0003 : 88 %
# Accuracy of  0108 : 97 %
# Accuracy of  0113 : 97 %
# Accuracy of  0054 : 80 %
# Accuracy of  0062 : 70 %
# Accuracy of  0150 : 97 %
# Accuracy of  0102 : 92 %
# Accuracy of  0076 : 97 %
# Accuracy of  0167 : 87 %
# Accuracy of  0042 : 79 %
# Accuracy of  0033 : 88 %
# Accuracy of  0157 : 97 %
# Accuracy of  0145 : 95 %
# Accuracy of  0048 : 83 %
# Accuracy of  0176 : 81 %
# Accuracy of  0186 : 87 %
# Accuracy of  0135 : 86 %
# Accuracy of  0060 : 97 %
# Accuracy of  0052 : 100 %
# Accuracy of  0160 : 95 %
# Accuracy of  0195 : 95 %
# Accuracy of  0058 : 80 %
# Accuracy of  0066 : 97 %
# Accuracy of  0103 : 92 %
# Accuracy of  0181 : 84 %
# Accuracy of  0056 : 86 %
# Accuracy of  0085 : 95 %
# Accuracy of  0050 : 95 %
# Accuracy of  0158 : 89 %
# Accuracy of  0015 : 88 %
# Accuracy of  0184 : 67 %
# Accuracy of  0142 : 90 %
# Accuracy of  0119 : 77 %
# Accuracy of  0096 : 90 %
# Accuracy of  0190 : 88 %
# Accuracy of  0081 : 95 %
# Accuracy of  0088 : 64 %
# Accuracy of  0144 : 86 %
# Accuracy of  0188 : 72 %
# Accuracy of  0178 : 97 %
# Accuracy of  0087 : 88 %
# Accuracy of  0074 : 76 %
# Accuracy of  0012 : 94 %
# Accuracy of  0007 : 84 %
# Accuracy of  0161 : 95 %
# Accuracy of  0086 : 80 %
# Accuracy of  0166 : 95 %
# Accuracy of  0057 : 86 %
# Accuracy of  0173 : 83 %
# Accuracy of  0040 : 94 %
# Accuracy of  0168 : 97 %
# Accuracy of  0137 : 95 %
# Accuracy of  0070 : 95 %
# Accuracy of  0109 : 93 %
# Accuracy of  0021 : 76 %
# Accuracy of  0043 : 73 %
# Accuracy of  0034 : 95 %
# Accuracy of  0162 : 91 %
# Accuracy of  0120 : 80 %
# Accuracy of  0039 : 86 %
# Accuracy of  0104 : 78 %
# Accuracy of  0133 : 85 %
# Accuracy of  0045 : 78 %
# Accuracy of  0153 : 93 %
# Accuracy of  0002 : 81 %
# Accuracy of  0134 : 88 %
# Accuracy of  0089 : 93 %
# Accuracy of  0037 : 94 %
# Accuracy of  0183 : 95 %
# Accuracy of  0116 : 97 %
# Accuracy of  0138 : 84 %
# Accuracy of  0147 : 97 %
# Accuracy of  0019 : 37 %
# Accuracy of  0155 : 92 %
# Accuracy of  0020 : 95 %
# Accuracy of  0023 : 69 %
# Accuracy of  0068 : 95 %
# Accuracy of  0011 : 92 %
# Accuracy of  0041 : 80 %
# Accuracy of  0140 : 80 %
# Accuracy of  0141 : 97 %
# Accuracy of  0090 : 85 %
# Accuracy of  0187 : 97 %
# Accuracy of  0055 : 79 %
# Accuracy of  0105 : 95 %
# Accuracy of  0064 : 37 %
# Accuracy of  0005 : 75 %
# Accuracy of  0182 : 86 %
# Accuracy of  0172 : 91 %
# Accuracy of  0100 : 100 %
# Accuracy of  0110 : 95 %
# Accuracy of  0080 : 90 %
# Accuracy of  0094 : 97 %
# Accuracy of  0030 : 87 %
# Accuracy of  0185 : 97 %
# Accuracy of  0053 : 95 %
# Accuracy of  0114 : 95 %
# Accuracy of  0008 : 75 %
# Accuracy of  0049 : 100 %
# Accuracy of  0191 : 95 %
# Accuracy of  0111 : 90 %
# Accuracy of  0179 : 86 %
# Accuracy of  0192 : 97 %
# Accuracy of  0126 : 100 %
# Accuracy of  0038 : 85 %
# Accuracy of  0082 : 82 %
# Accuracy of  0028 : 97 %
# Accuracy of  0013 : 82 %
# Accuracy of  0194 : 97 %
# Accuracy of  0129 : 81 %
# Accuracy of  0014 : 68 %
# Accuracy of  0099 : 100 %
# Accuracy of  0115 : 88 %
# Accuracy of  0123 : 91 %
# Accuracy of  0112 : 91 %
# Accuracy of  0077 : 85 %
# Accuracy of  0084 : 78 %
# Accuracy of  0196 : 92 %
# Accuracy of  0046 : 79 %
# Accuracy of  0125 : 83 %
# Accuracy of  0018 : 90 %
# Accuracy of  0117 : 92 %
# Accuracy of  0073 : 77 %
# Accuracy of  0016 : 69 %
# Accuracy of  0164 : 95 %
# Accuracy of  0165 : 97 %
# Accuracy of  0036 : 95 %
# Accuracy of  0180 : 64 %
# Accuracy of  0031 : 65 %
# Accuracy of  0193 : 95 %
# Accuracy of  0170 : 93 %
# Accuracy of  0022 : 57 %
# Accuracy of  0118 : 92 %
# Accuracy of  0083 : 70 %
# Accuracy of  0004 : 97 %
# Accuracy of  0148 : 88 %
# Accuracy of  0095 : 93 %
# Accuracy of  0159 : 91 %
# Accuracy of  0078 : 94 %
# Accuracy of  0139 : 92 %
# Accuracy of  0107 : 90 %
# Accuracy of  0071 : 40 %
# Accuracy of  0093 : 100 %
# Accuracy of  0017 : 77 %
