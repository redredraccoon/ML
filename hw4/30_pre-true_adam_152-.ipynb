# %%
import torch
import torch.nn as nn
#from models import VGG16
import torchvision.models as models
from dataset import IMAGE_Dataset
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from pathlib import Path
import copy
import matplotlib.pyplot as plt

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
##REPRODUCIBILITY
torch.manual_seed(123)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
CUDA_DEVICES = 0
DATASET_ROOT = './new/train'
DATASET_ROOT_TEST = './new/test'

# %%
data_transform = transforms.Compose([
		transforms.Resize((224,224)),
		transforms.ToTensor(),
		transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
	])
#print(DATASET_ROOT)
#train_load
train_set = IMAGE_Dataset(Path(DATASET_ROOT), data_transform)
train_data_loader = DataLoader(dataset=train_set, batch_size=32, shuffle=True, num_workers=1)
#test_load
test_set = IMAGE_Dataset(Path(DATASET_ROOT_TEST), data_transform)
test_data_loader = DataLoader(dataset=test_set, batch_size=32, shuffle=True, num_workers=1)

print(train_set.num_classes)
# Out:
# 196

# %%
model = models.resnet152(pretrained=True)

# %%
fc_features = model.fc.in_features
model.fc = nn.Linear(fc_features,196)

model.fc
# Out:
# Linear(in_features=2048, out_features=196, bias=True)

# %%
#model = VGG16(num_classes=train_set.num_classes)
model = model.cuda(CUDA_DEVICES)
model.train()

best_model_params = copy.deepcopy(model.state_dict())
best_acc = 0.0
num_epochs = 30
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model.parameters(), lr=0.001)
#optimizer = torch.optim.SGD(params=model.parameters(), lr=0.001, momentum=0.9)

# %%
train_loss_list = [] 
train_acc_list = [] 
epoch_list = []

test_loss_list = [] 
test_acc_list = [] 
test_epoch_list = []

# %%
for epoch in range(num_epochs):
        print(f'Epoch: {epoch + 1}/{num_epochs}')
        print('-' * len(f'Epoch: {epoch + 1}/{num_epochs}'))

        training_loss = 0.0
        training_corrects = 0

        testing_loss = 0.0
        testing_corrects = 0

        for i, (inputs, labels) in enumerate(train_data_loader):
                inputs = Variable(inputs.cuda(CUDA_DEVICES))
                labels = Variable(labels.cuda(CUDA_DEVICES))			

                optimizer.zero_grad()

                outputs = model(inputs)
                _, preds = torch.max(outputs.data, 1)
                loss = criterion(outputs, labels)

                loss.backward()
                optimizer.step()

                training_loss += loss.item() * inputs.size(0)
                #revise loss.data[0]-->loss.item()
                training_corrects += torch.sum(preds == labels.data)
                #print(f'training_corrects: {training_corrects}')

        training_loss = training_loss / len(train_set)
        training_acc =training_corrects.double() /len(train_set)

        train_loss_list.append(training_loss)
        train_acc_list.append(training_acc)
        epoch_list.append(epoch+1)

        classes = [_dir.name for _dir in Path(DATASET_ROOT_TEST).glob('*')]
        total_correct = 0
        total = 0
        class_correct = list(0. for i in enumerate(classes))
        class_total = list(0. for i in enumerate(classes))
        with torch.no_grad():
            for inputs, labels in test_data_loader:
                    inputs = Variable(inputs.cuda(CUDA_DEVICES))
                    labels = Variable(labels.cuda(CUDA_DEVICES))
                    outputs = model(inputs)
                    _, predicted = torch.max(outputs.data, 1)
                    loss_test = criterion(outputs, labels)
                    # test
                    testing_loss += loss_test.item() * inputs.size(0)
                    testing_corrects += torch.sum(predicted == labels.data)
                    # totoal
                    total += labels.size(0)
                    total_correct += (predicted == labels).sum().item()
                    c = (predicted == labels).squeeze()
                    # batch size
                    for i in range(labels.size(0)):
                        label =labels[i]
                        class_correct[label] += c[i].item()
                        class_total[label] += 1
                
        testing_loss = testing_loss / len(test_set)
        testing_acc =testing_corrects.double() /len(test_set)

        test_loss_list.append(testing_loss)
        test_acc_list.append(testing_acc)
        test_epoch_list.append(epoch+1)


        #print(training_acc.type())
        #print(f'training_corrects: {training_corrects}\tlen(train_set):{len(train_set)}\n')
        print(f'Training loss: {training_loss:.4f}\taccuracy: {training_acc:.4f}\n')
        
        
        if training_acc > best_acc:
                best_acc = training_acc
                best_model_params = copy.deepcopy(model.state_dict())

model.load_state_dict(best_model_params)
# Out:
# Epoch: 1/30
# -----------
# Training loss: 5.2779	accuracy: 0.0069
#
# Epoch: 2/30
# -----------
# Training loss: 5.1157	accuracy: 0.0128
#
# Epoch: 3/30
# -----------
# Training loss: 4.9850	accuracy: 0.0199
#
# Epoch: 4/30
# -----------
# Training loss: 4.7265	accuracy: 0.0349
#
# Epoch: 5/30
# -----------
# Training loss: 4.3954	accuracy: 0.0597
#
# Epoch: 6/30
# -----------
# Training loss: 4.0801	accuracy: 0.0808
#
# Epoch: 7/30
# -----------
# Training loss: 3.7547	accuracy: 0.1130
#
# Epoch: 8/30
# -----------
# Training loss: 3.3390	accuracy: 0.1735
#
# Epoch: 9/30
# -----------
# Training loss: 2.8717	accuracy: 0.2547
#
# Epoch: 10/30
# ------------
# Training loss: 2.3988	accuracy: 0.3517
#
# Epoch: 11/30
# ------------
# Training loss: 1.9045	accuracy: 0.4673
#
# Epoch: 12/30
# ------------
# Training loss: 1.5449	accuracy: 0.5559
#
# Epoch: 13/30
# ------------
# Training loss: 1.2321	accuracy: 0.6380
#
# Epoch: 14/30
# ------------
# Training loss: 0.9246	accuracy: 0.7182
#
# Epoch: 15/30
# ------------
# Training loss: 0.8177	accuracy: 0.7495
#
# Epoch: 16/30
# ------------
# Training loss: 0.5363	accuracy: 0.8326
#
# Epoch: 17/30
# ------------
# Training loss: 0.4119	accuracy: 0.8706
#
# Epoch: 18/30
# ------------
# Training loss: 0.2884	accuracy: 0.9134
#
# Epoch: 19/30
# ------------
# Training loss: 0.2328	accuracy: 0.9269
#
# Epoch: 20/30
# ------------
# Training loss: 0.2189	accuracy: 0.9341
#
# Epoch: 21/30
# ------------
# Training loss: 0.2154	accuracy: 0.9359
#
# Epoch: 22/30
# ------------
# Training loss: 0.2732	accuracy: 0.9156
#
# Epoch: 23/30
# ------------
# Training loss: 0.1576	accuracy: 0.9522
#
# Epoch: 24/30
# ------------
# Training loss: 0.1322	accuracy: 0.9613
#
# Epoch: 25/30
# ------------
# Training loss: 0.2063	accuracy: 0.9374
#
# Epoch: 26/30
# ------------
# Training loss: 0.1444	accuracy: 0.9581
#
# Epoch: 27/30
# ------------
# Training loss: 0.0965	accuracy: 0.9738
#
# Epoch: 28/30
# ------------
# Training loss: 0.1314	accuracy: 0.9607
#
# Epoch: 29/30
# ------------
# Training loss: 0.1929	accuracy: 0.9434
#
# Epoch: 30/30
# ------------
# Training loss: 0.1293	accuracy: 0.9627

# %%
#model.load_state_dict(best_model_params)
#torch.save(model, f'without,model-{best_acc:.02f}-best_train_acc.pth')

# %%
plt.plot(epoch_list, train_loss_list, label='train')
plt.plot(test_epoch_list, test_loss_list, label='test')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend(['train','test'], loc='upper right')
plt.savefig("loss.png",dpi=250,format="png")
plt.tight_layout()
plt.show()

plt.plot(epoch_list, train_acc_list, label='train')
plt.plot(test_epoch_list, test_acc_list, label='test')
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.legend(['train','test'], loc='upper right')
plt.savefig("accuracy.png",dpi=250,format="png")
plt.tight_layout()
plt.show()

# %%
print('Accuracy on the ALL test images: %d %%'
      % (100 * total_correct / total))

for i, c in enumerate(classes):
    print('Accuracy of %5s : %2d %%' % (
    c, 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy on the ALL test images: 56 %
# Accuracy of  0149 : 52 %
# Accuracy of  0025 : 58 %
# Accuracy of  0174 : 63 %
# Accuracy of  0151 : 48 %
# Accuracy of  0132 : 69 %
# Accuracy of  0010 : 48 %
# Accuracy of  0122 : 62 %
# Accuracy of  0143 : 65 %
# Accuracy of  0026 : 50 %
# Accuracy of  0146 : 88 %
# Accuracy of  0101 : 38 %
# Accuracy of  0075 : 61 %
# Accuracy of  0121 : 47 %
# Accuracy of  0177 : 56 %
# Accuracy of  0130 : 63 %
# Accuracy of  0067 : 65 %
# Accuracy of  0175 : 73 %
# Accuracy of  0154 : 61 %
# Accuracy of  0079 : 58 %
# Accuracy of  0131 : 50 %
# Accuracy of  0059 : 52 %
# Accuracy of  0169 : 63 %
# Accuracy of  0069 : 55 %
# Accuracy of  0072 : 44 %
# Accuracy of  0128 : 35 %
# Accuracy of  0124 : 71 %
# Accuracy of  0009 : 31 %
# Accuracy of  0032 : 29 %
# Accuracy of  0063 : 56 %
# Accuracy of  0171 : 78 %
# Accuracy of  0024 : 53 %
# Accuracy of  0152 : 68 %
# Accuracy of  0189 : 90 %
# Accuracy of  0044 : 47 %
# Accuracy of  0029 : 30 %
# Accuracy of  0127 : 63 %
# Accuracy of  0136 : 25 %
# Accuracy of  0163 : 58 %
# Accuracy of  0061 : 37 %
# Accuracy of  0047 : 54 %
# Accuracy of  0097 : 50 %
# Accuracy of  0092 : 32 %
# Accuracy of  0091 : 94 %
# Accuracy of  0006 : 38 %
# Accuracy of  0065 : 64 %
# Accuracy of  0001 : 70 %
# Accuracy of  0098 : 43 %
# Accuracy of  0051 : 55 %
# Accuracy of  0156 : 53 %
# Accuracy of  0027 : 60 %
# Accuracy of  0106 : 54 %
# Accuracy of  0035 : 39 %
# Accuracy of  0003 : 77 %
# Accuracy of  0108 : 70 %
# Accuracy of  0113 : 85 %
# Accuracy of  0054 : 27 %
# Accuracy of  0062 : 43 %
# Accuracy of  0150 : 58 %
# Accuracy of  0102 : 82 %
# Accuracy of  0076 : 51 %
# Accuracy of  0167 : 62 %
# Accuracy of  0042 : 64 %
# Accuracy of  0033 : 69 %
# Accuracy of  0157 : 80 %
# Accuracy of  0145 : 72 %
# Accuracy of  0048 : 69 %
# Accuracy of  0176 : 71 %
# Accuracy of  0186 : 12 %
# Accuracy of  0135 : 67 %
# Accuracy of  0060 : 86 %
# Accuracy of  0052 : 34 %
# Accuracy of  0160 : 47 %
# Accuracy of  0195 : 58 %
# Accuracy of  0058 : 48 %
# Accuracy of  0066 : 56 %
# Accuracy of  0103 : 64 %
# Accuracy of  0181 : 28 %
# Accuracy of  0056 :  0 %
# Accuracy of  0085 : 86 %
# Accuracy of  0050 : 73 %
# Accuracy of  0158 : 27 %
# Accuracy of  0015 : 86 %
# Accuracy of  0184 : 62 %
# Accuracy of  0142 : 59 %
# Accuracy of  0119 : 70 %
# Accuracy of  0096 : 59 %
# Accuracy of  0190 : 55 %
# Accuracy of  0081 : 71 %
# Accuracy of  0088 : 48 %
# Accuracy of  0144 : 34 %
# Accuracy of  0188 : 48 %
# Accuracy of  0178 : 58 %
# Accuracy of  0087 : 52 %
# Accuracy of  0074 : 18 %
# Accuracy of  0012 : 52 %
# Accuracy of  0007 : 48 %
# Accuracy of  0161 : 79 %
# Accuracy of  0086 : 88 %
# Accuracy of  0166 : 80 %
# Accuracy of  0057 : 45 %
# Accuracy of  0173 : 55 %
# Accuracy of  0040 : 69 %
# Accuracy of  0168 : 69 %
# Accuracy of  0137 : 76 %
# Accuracy of  0070 : 83 %
# Accuracy of  0109 : 63 %
# Accuracy of  0021 : 38 %
# Accuracy of  0043 : 34 %
# Accuracy of  0034 : 56 %
# Accuracy of  0162 : 64 %
# Accuracy of  0120 : 69 %
# Accuracy of  0039 : 63 %
# Accuracy of  0104 : 38 %
# Accuracy of  0133 : 45 %
# Accuracy of  0045 : 56 %
# Accuracy of  0153 : 79 %
# Accuracy of  0002 : 68 %
# Accuracy of  0134 : 61 %
# Accuracy of  0089 : 68 %
# Accuracy of  0037 : 86 %
# Accuracy of  0183 : 66 %
# Accuracy of  0116 : 81 %
# Accuracy of  0138 : 69 %
# Accuracy of  0147 : 59 %
# Accuracy of  0019 : 17 %
# Accuracy of  0155 : 59 %
# Accuracy of  0020 : 39 %
# Accuracy of  0023 : 15 %
# Accuracy of  0068 : 52 %
# Accuracy of  0011 : 60 %
# Accuracy of  0041 : 57 %
# Accuracy of  0140 : 57 %
# Accuracy of  0141 : 64 %
# Accuracy of  0090 : 39 %
# Accuracy of  0187 : 53 %
# Accuracy of  0055 : 74 %
# Accuracy of  0105 : 69 %
# Accuracy of  0064 : 68 %
# Accuracy of  0005 : 52 %
# Accuracy of  0182 : 43 %
# Accuracy of  0172 : 57 %
# Accuracy of  0100 : 42 %
# Accuracy of  0110 : 60 %
# Accuracy of  0080 : 69 %
# Accuracy of  0094 : 65 %
# Accuracy of  0030 : 41 %
# Accuracy of  0185 : 42 %
# Accuracy of  0053 : 54 %
# Accuracy of  0114 : 46 %
# Accuracy of  0008 : 40 %
# Accuracy of  0049 : 81 %
# Accuracy of  0191 : 63 %
# Accuracy of  0111 : 61 %
# Accuracy of  0179 : 62 %
# Accuracy of  0192 : 57 %
# Accuracy of  0126 : 45 %
# Accuracy of  0038 : 50 %
# Accuracy of  0082 : 62 %
# Accuracy of  0028 : 48 %
# Accuracy of  0013 : 39 %
# Accuracy of  0194 : 73 %
# Accuracy of  0129 : 44 %
# Accuracy of  0014 : 45 %
# Accuracy of  0099 : 77 %
# Accuracy of  0115 : 40 %
# Accuracy of  0123 : 75 %
# Accuracy of  0112 : 40 %
# Accuracy of  0077 : 47 %
# Accuracy of  0084 : 59 %
# Accuracy of  0196 : 62 %
# Accuracy of  0046 : 51 %
# Accuracy of  0125 : 44 %
# Accuracy of  0018 : 45 %
# Accuracy of  0117 : 61 %
# Accuracy of  0073 : 55 %
# Accuracy of  0016 : 20 %
# Accuracy of  0164 : 58 %
# Accuracy of  0165 : 75 %
# Accuracy of  0036 : 46 %
# Accuracy of  0180 : 19 %
# Accuracy of  0031 : 45 %
# Accuracy of  0193 : 50 %
# Accuracy of  0170 : 47 %
# Accuracy of  0022 : 21 %
# Accuracy of  0118 : 78 %
# Accuracy of  0083 : 40 %
# Accuracy of  0004 : 54 %
# Accuracy of  0148 : 66 %
# Accuracy of  0095 : 60 %
# Accuracy of  0159 : 69 %
# Accuracy of  0078 : 59 %
# Accuracy of  0139 : 69 %
# Accuracy of  0107 : 50 %
# Accuracy of  0071 :  8 %
# Accuracy of  0093 : 71 %
# Accuracy of  0017 : 47 %
