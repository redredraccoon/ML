# %%
import torch
import torch.nn as nn
#from models import VGG16
import torchvision.models as models
from dataset import IMAGE_Dataset
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from pathlib import Path
import copy
import matplotlib.pyplot as plt

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
##REPRODUCIBILITY
torch.manual_seed(123)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
CUDA_DEVICES = 0
DATASET_ROOT = './new/train'
DATASET_ROOT_TEST = './new/test'

# %%
data_transform = transforms.Compose([
		transforms.Resize((224,224)),
		transforms.ToTensor(),
		transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
	])
#print(DATASET_ROOT)
#train_load
train_set = IMAGE_Dataset(Path(DATASET_ROOT), data_transform)
train_data_loader = DataLoader(dataset=train_set, batch_size=32, shuffle=True, num_workers=1)
#test_load
test_set = IMAGE_Dataset(Path(DATASET_ROOT_TEST), data_transform)
test_data_loader = DataLoader(dataset=test_set, batch_size=32, shuffle=True, num_workers=1)

print(train_set.num_classes)
# Out:
# 196

# %%
model = models.resnet152(pretrained=True)

# %%
fc_features = model.fc.in_features
model.fc = nn.Linear(fc_features,196)

model.fc
# Out:
# Linear(in_features=2048, out_features=196, bias=True)

# %%
#model = VGG16(num_classes=train_set.num_classes)
model = model.cuda(CUDA_DEVICES)
model.train()

best_model_params = copy.deepcopy(model.state_dict())
best_acc = 0.0
num_epochs = 40
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model.parameters(), lr=0.0001)
#optimizer = torch.optim.SGD(params=model.parameters(), lr=0.001, momentum=0.9)

# %%
train_loss_list = [] 
train_acc_list = [] 
epoch_list = []

test_loss_list = [] 
test_acc_list = [] 
test_epoch_list = []

# %%
for epoch in range(num_epochs):
        print(f'Epoch: {epoch + 1}/{num_epochs}')
        print('-' * len(f'Epoch: {epoch + 1}/{num_epochs}'))

        training_loss = 0.0
        training_corrects = 0

        testing_loss = 0.0
        testing_corrects = 0

        for i, (inputs, labels) in enumerate(train_data_loader):
                inputs = Variable(inputs.cuda(CUDA_DEVICES))
                labels = Variable(labels.cuda(CUDA_DEVICES))			

                optimizer.zero_grad()

                outputs = model(inputs)
                _, preds = torch.max(outputs.data, 1)
                loss = criterion(outputs, labels)

                loss.backward()
                optimizer.step()

                training_loss += loss.item() * inputs.size(0)
                #revise loss.data[0]-->loss.item()
                training_corrects += torch.sum(preds == labels.data)
                #print(f'training_corrects: {training_corrects}')

        training_loss = training_loss / len(train_set)
        training_acc =training_corrects.double() /len(train_set)

        train_loss_list.append(training_loss)
        train_acc_list.append(training_acc)
        epoch_list.append(epoch+1)

        classes = [_dir.name for _dir in Path(DATASET_ROOT_TEST).glob('*')]
        total_correct = 0
        total = 0
        class_correct = list(0. for i in enumerate(classes))
        class_total = list(0. for i in enumerate(classes))
        with torch.no_grad():
            for inputs, labels in test_data_loader:
                    inputs = Variable(inputs.cuda(CUDA_DEVICES))
                    labels = Variable(labels.cuda(CUDA_DEVICES))
                    outputs = model(inputs)
                    _, predicted = torch.max(outputs.data, 1)
                    loss_test = criterion(outputs, labels)
                    # test
                    testing_loss += loss_test.item() * inputs.size(0)
                    testing_corrects += torch.sum(predicted == labels.data)
                    # totoal
                    total += labels.size(0)
                    total_correct += (predicted == labels).sum().item()
                    c = (predicted == labels).squeeze()
                    # batch size
                    for i in range(labels.size(0)):
                        label =labels[i]
                        class_correct[label] += c[i].item()
                        class_total[label] += 1
                
        testing_loss = testing_loss / len(test_set)
        testing_acc =testing_corrects.double() /len(test_set)

        test_loss_list.append(testing_loss)
        test_acc_list.append(testing_acc)
        test_epoch_list.append(epoch+1)


        #print(training_acc.type())
        #print(f'training_corrects: {training_corrects}\tlen(train_set):{len(train_set)}\n')
        print(f'Training loss: {training_loss:.4f}\taccuracy: {training_acc:.4f}\n')
        
        
        if training_acc > best_acc:
                best_acc = training_acc
                best_model_params = copy.deepcopy(model.state_dict())

model.load_state_dict(best_model_params)
# Out:
# Epoch: 1/40
# -----------
# Training loss: 3.6769	accuracy: 0.2507
#
# Epoch: 2/40
# -----------
# Training loss: 1.2223	accuracy: 0.7342
#
# Epoch: 3/40
# -----------
# Training loss: 0.4082	accuracy: 0.9174
#
# Epoch: 4/40
# -----------
# Training loss: 0.1807	accuracy: 0.9643
#
# Epoch: 5/40
# -----------
# Training loss: 0.0857	accuracy: 0.9865
#
# Epoch: 6/40
# -----------
# Training loss: 0.0632	accuracy: 0.9899
#
# Epoch: 7/40
# -----------
# Training loss: 0.0610	accuracy: 0.9893
#
# Epoch: 8/40
# -----------
# Training loss: 0.1173	accuracy: 0.9774
#
# Epoch: 9/40
# -----------
# Training loss: 0.1481	accuracy: 0.9676
#
# Epoch: 10/40
# ------------
# Training loss: 0.0869	accuracy: 0.9817
#
# Epoch: 11/40
# ------------
# Training loss: 0.0435	accuracy: 0.9921
#
# Epoch: 12/40
# ------------
# Training loss: 0.0195	accuracy: 0.9956
#
# Epoch: 13/40
# ------------
# Training loss: 0.0175	accuracy: 0.9962
#
# Epoch: 14/40
# ------------
# Training loss: 0.0396	accuracy: 0.9917
#
# Epoch: 15/40
# ------------
# Training loss: 0.1548	accuracy: 0.9623
#
# Epoch: 16/40
# ------------
# Training loss: 0.0909	accuracy: 0.9788
#
# Epoch: 17/40
# ------------
# Training loss: 0.0452	accuracy: 0.9888
#
# Epoch: 18/40
# ------------
# Training loss: 0.0322	accuracy: 0.9918
#
# Epoch: 19/40
# ------------
# Training loss: 0.0271	accuracy: 0.9934
#
# Epoch: 20/40
# ------------
# Training loss: 0.0384	accuracy: 0.9914
#
# Epoch: 21/40
# ------------
# Training loss: 0.0404	accuracy: 0.9901
#
# Epoch: 22/40
# ------------
# Training loss: 0.0194	accuracy: 0.9951
#
# Epoch: 23/40
# ------------
# Training loss: 0.0803	accuracy: 0.9806
#
# Epoch: 24/40
# ------------
# Training loss: 0.0666	accuracy: 0.9837
#
# Epoch: 25/40
# ------------
# Training loss: 0.0574	accuracy: 0.9864
#
# Epoch: 26/40
# ------------
# Training loss: 0.0510	accuracy: 0.9856
#
# Epoch: 27/40
# ------------
# Training loss: 0.0214	accuracy: 0.9957
#
# Epoch: 28/40
# ------------
# Training loss: 0.0095	accuracy: 0.9978
#
# Epoch: 29/40
# ------------
# Training loss: 0.0055	accuracy: 0.9979
#
# Epoch: 30/40
# ------------
# Training loss: 0.0049	accuracy: 0.9980
#
# Epoch: 31/40
# ------------
# Training loss: 0.0046	accuracy: 0.9979
#
# Epoch: 32/40
# ------------
# Training loss: 0.0044	accuracy: 0.9982
#
# Epoch: 33/40
# ------------
# Training loss: 0.0043	accuracy: 0.9978
#
# Epoch: 34/40
# ------------
# Training loss: 0.0042	accuracy: 0.9979
#
# Epoch: 35/40
# ------------
# Training loss: 0.0040	accuracy: 0.9979
#
# Epoch: 36/40
# ------------
# Training loss: 0.0038	accuracy: 0.9978
#
# Epoch: 37/40
# ------------
# Training loss: 0.0042	accuracy: 0.9978
#
# Epoch: 38/40
# ------------
# Training loss: 0.0040	accuracy: 0.9979
#
# Epoch: 39/40
# ------------
# Training loss: 0.0046	accuracy: 0.9978
#
# Epoch: 40/40
# ------------
# Training loss: 0.0042	accuracy: 0.9979

# %%
#model.load_state_dict(best_model_params)
#torch.save(model, f'without,model-{best_acc:.02f}-best_train_acc.pth')

# %%
plt.plot(epoch_list, train_loss_list, label='train')
plt.plot(test_epoch_list, test_loss_list, label='test')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend(['train','test'], loc='upper right')
plt.savefig("loss.png",dpi=250,format="png")
plt.tight_layout()
plt.show()

plt.plot(epoch_list, train_acc_list, label='train')
plt.plot(test_epoch_list, test_acc_list, label='test')
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.legend(['train','test'], loc='upper right')
plt.savefig("accuracy.png",dpi=250,format="png")
plt.tight_layout()
plt.show()

# %%
print('Accuracy on the ALL test images: %d %%'
      % (100 * total_correct / total))

for i, c in enumerate(classes):
    print('Accuracy of %5s : %2d %%' % (
    c, 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy on the ALL test images: 90 %
# Accuracy of  0149 : 90 %
# Accuracy of  0025 : 84 %
# Accuracy of  0174 : 82 %
# Accuracy of  0151 : 93 %
# Accuracy of  0132 : 97 %
# Accuracy of  0010 : 75 %
# Accuracy of  0122 : 90 %
# Accuracy of  0143 : 95 %
# Accuracy of  0026 : 94 %
# Accuracy of  0146 : 100 %
# Accuracy of  0101 : 97 %
# Accuracy of  0075 : 77 %
# Accuracy of  0121 : 100 %
# Accuracy of  0177 : 86 %
# Accuracy of  0130 : 97 %
# Accuracy of  0067 : 92 %
# Accuracy of  0175 : 90 %
# Accuracy of  0154 : 100 %
# Accuracy of  0079 : 85 %
# Accuracy of  0131 : 95 %
# Accuracy of  0059 : 88 %
# Accuracy of  0169 : 92 %
# Accuracy of  0069 : 68 %
# Accuracy of  0072 : 93 %
# Accuracy of  0128 : 92 %
# Accuracy of  0124 : 92 %
# Accuracy of  0009 : 87 %
# Accuracy of  0032 : 97 %
# Accuracy of  0063 : 100 %
# Accuracy of  0171 : 91 %
# Accuracy of  0024 : 93 %
# Accuracy of  0152 : 85 %
# Accuracy of  0189 : 100 %
# Accuracy of  0044 : 97 %
# Accuracy of  0029 : 88 %
# Accuracy of  0127 : 92 %
# Accuracy of  0136 : 87 %
# Accuracy of  0163 : 94 %
# Accuracy of  0061 : 97 %
# Accuracy of  0047 : 97 %
# Accuracy of  0097 : 83 %
# Accuracy of  0092 : 95 %
# Accuracy of  0091 : 89 %
# Accuracy of  0006 : 90 %
# Accuracy of  0065 : 91 %
# Accuracy of  0001 : 95 %
# Accuracy of  0098 : 91 %
# Accuracy of  0051 : 100 %
# Accuracy of  0156 : 97 %
# Accuracy of  0027 : 94 %
# Accuracy of  0106 : 95 %
# Accuracy of  0035 : 97 %
# Accuracy of  0003 : 95 %
# Accuracy of  0108 : 97 %
# Accuracy of  0113 : 90 %
# Accuracy of  0054 : 75 %
# Accuracy of  0062 : 81 %
# Accuracy of  0150 : 94 %
# Accuracy of  0102 : 92 %
# Accuracy of  0076 : 93 %
# Accuracy of  0167 : 85 %
# Accuracy of  0042 : 73 %
# Accuracy of  0033 : 90 %
# Accuracy of  0157 : 94 %
# Accuracy of  0145 : 93 %
# Accuracy of  0048 : 90 %
# Accuracy of  0176 : 92 %
# Accuracy of  0186 : 87 %
# Accuracy of  0135 : 90 %
# Accuracy of  0060 : 97 %
# Accuracy of  0052 : 100 %
# Accuracy of  0160 : 93 %
# Accuracy of  0195 : 93 %
# Accuracy of  0058 : 88 %
# Accuracy of  0066 : 90 %
# Accuracy of  0103 : 94 %
# Accuracy of  0181 : 89 %
# Accuracy of  0056 : 82 %
# Accuracy of  0085 : 97 %
# Accuracy of  0050 : 100 %
# Accuracy of  0158 : 96 %
# Accuracy of  0015 : 88 %
# Accuracy of  0184 : 67 %
# Accuracy of  0142 : 93 %
# Accuracy of  0119 : 82 %
# Accuracy of  0096 : 97 %
# Accuracy of  0190 : 93 %
# Accuracy of  0081 : 97 %
# Accuracy of  0088 : 79 %
# Accuracy of  0144 : 91 %
# Accuracy of  0188 : 90 %
# Accuracy of  0178 : 97 %
# Accuracy of  0087 : 88 %
# Accuracy of  0074 : 83 %
# Accuracy of  0012 : 86 %
# Accuracy of  0007 : 84 %
# Accuracy of  0161 : 95 %
# Accuracy of  0086 : 92 %
# Accuracy of  0166 : 85 %
# Accuracy of  0057 : 89 %
# Accuracy of  0173 : 93 %
# Accuracy of  0040 : 92 %
# Accuracy of  0168 : 100 %
# Accuracy of  0137 : 97 %
# Accuracy of  0070 : 95 %
# Accuracy of  0109 : 97 %
# Accuracy of  0021 : 88 %
# Accuracy of  0043 : 71 %
# Accuracy of  0034 : 97 %
# Accuracy of  0162 : 93 %
# Accuracy of  0120 : 85 %
# Accuracy of  0039 : 91 %
# Accuracy of  0104 : 90 %
# Accuracy of  0133 : 90 %
# Accuracy of  0045 : 87 %
# Accuracy of  0153 : 90 %
# Accuracy of  0002 : 78 %
# Accuracy of  0134 : 91 %
# Accuracy of  0089 : 95 %
# Accuracy of  0037 : 97 %
# Accuracy of  0183 : 97 %
# Accuracy of  0116 : 100 %
# Accuracy of  0138 : 92 %
# Accuracy of  0147 : 93 %
# Accuracy of  0019 : 60 %
# Accuracy of  0155 : 92 %
# Accuracy of  0020 : 91 %
# Accuracy of  0023 : 76 %
# Accuracy of  0068 : 92 %
# Accuracy of  0011 : 84 %
# Accuracy of  0041 : 82 %
# Accuracy of  0140 : 83 %
# Accuracy of  0141 : 97 %
# Accuracy of  0090 : 80 %
# Accuracy of  0187 : 97 %
# Accuracy of  0055 : 84 %
# Accuracy of  0105 : 95 %
# Accuracy of  0064 : 51 %
# Accuracy of  0005 : 80 %
# Accuracy of  0182 : 95 %
# Accuracy of  0172 : 93 %
# Accuracy of  0100 : 100 %
# Accuracy of  0110 : 95 %
# Accuracy of  0080 : 97 %
# Accuracy of  0094 : 95 %
# Accuracy of  0030 : 90 %
# Accuracy of  0185 : 100 %
# Accuracy of  0053 : 97 %
# Accuracy of  0114 : 93 %
# Accuracy of  0008 : 77 %
# Accuracy of  0049 : 100 %
# Accuracy of  0191 : 100 %
# Accuracy of  0111 : 92 %
# Accuracy of  0179 : 82 %
# Accuracy of  0192 : 97 %
# Accuracy of  0126 : 92 %
# Accuracy of  0038 : 97 %
# Accuracy of  0082 : 95 %
# Accuracy of  0028 : 100 %
# Accuracy of  0013 : 92 %
# Accuracy of  0194 : 95 %
# Accuracy of  0129 : 97 %
# Accuracy of  0014 : 61 %
# Accuracy of  0099 : 100 %
# Accuracy of  0115 : 91 %
# Accuracy of  0123 : 86 %
# Accuracy of  0112 : 88 %
# Accuracy of  0077 : 92 %
# Accuracy of  0084 : 59 %
# Accuracy of  0196 : 100 %
# Accuracy of  0046 : 81 %
# Accuracy of  0125 : 83 %
# Accuracy of  0018 : 80 %
# Accuracy of  0117 : 95 %
# Accuracy of  0073 : 84 %
# Accuracy of  0016 : 76 %
# Accuracy of  0164 : 95 %
# Accuracy of  0165 : 97 %
# Accuracy of  0036 : 82 %
# Accuracy of  0180 : 73 %
# Accuracy of  0031 : 79 %
# Accuracy of  0193 : 95 %
# Accuracy of  0170 : 97 %
# Accuracy of  0022 : 61 %
# Accuracy of  0118 : 97 %
# Accuracy of  0083 : 80 %
# Accuracy of  0004 : 100 %
# Accuracy of  0148 : 88 %
# Accuracy of  0095 : 86 %
# Accuracy of  0159 : 100 %
# Accuracy of  0078 : 89 %
# Accuracy of  0139 : 100 %
# Accuracy of  0107 : 95 %
# Accuracy of  0071 : 48 %
# Accuracy of  0093 : 100 %
# Accuracy of  0017 : 75 %
