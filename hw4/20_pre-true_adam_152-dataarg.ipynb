# %%
import torch
import torch.nn as nn
#from models import VGG16
import torchvision.models as models
from dataset import IMAGE_Dataset
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from pathlib import Path
import copy
import matplotlib.pyplot as plt
import torch.nn.functional as F

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
##REPRODUCIBILITY
torch.manual_seed(123)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
CUDA_DEVICES = 0
DATASET_ROOT = './new/train'
DATASET_ROOT_TEST = './new/test'

# %%
data_transform = transforms.Compose([
		transforms.RandomResizedCrop(224, interpolation=2),
		transforms.RandomHorizontalFlip(),
		transforms.ToTensor(),
		transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
	])
#print(DATASET_ROOT)
#train_load
train_set = IMAGE_Dataset(Path(DATASET_ROOT), data_transform)
train_data_loader = DataLoader(dataset=train_set, batch_size=32, shuffle=True, num_workers=1)
#test_load
test_set = IMAGE_Dataset(Path(DATASET_ROOT_TEST), data_transform)
test_data_loader = DataLoader(dataset=test_set, batch_size=32, shuffle=True, num_workers=1)

print(train_set.num_classes)
# Out:
# 196

# %%
model = models.resnet152(pretrained=True)

# %%
fc_features = model.fc.in_features
model.fc = nn.Linear(fc_features,196)

model.fc
# Out:
# Linear(in_features=2048, out_features=196, bias=True)

# %%
#model = VGG16(num_classes=train_set.num_classes)
model = model.cuda(CUDA_DEVICES)
model.train()

best_model_params = copy.deepcopy(model.state_dict())
best_acc = 0.0
num_epochs = 20
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model.parameters(), lr=0.001)
#optimizer = torch.optim.SGD(params=model.parameters(), lr=0.001, momentum=0.9)

# %%
train_loss_list = [] 
train_acc_list = [] 
epoch_list = []

test_loss_list = [] 
test_acc_list = [] 
test_epoch_list = []

# %%
for epoch in range(num_epochs):
        print(f'Epoch: {epoch + 1}/{num_epochs}')
        print('-' * len(f'Epoch: {epoch + 1}/{num_epochs}'))

        training_loss = 0.0
        training_corrects = 0

        testing_loss = 0.0
        testing_corrects = 0

        for i, (inputs, labels) in enumerate(train_data_loader):
                inputs = Variable(inputs.cuda(CUDA_DEVICES))
                labels = Variable(labels.cuda(CUDA_DEVICES))			

                optimizer.zero_grad()

                outputs = model(inputs)
                _, preds = torch.max(outputs.data, 1)
                loss = criterion(outputs, labels)

                loss.backward()
                optimizer.step()

                training_loss += loss.item() * inputs.size(0)
                #revise loss.data[0]-->loss.item()
                training_corrects += torch.sum(preds == labels.data)
                #print(f'training_corrects: {training_corrects}')

        training_loss = training_loss / len(train_set)
        training_acc =training_corrects.double() /len(train_set)

        train_loss_list.append(training_loss)
        train_acc_list.append(training_acc)
        epoch_list.append(epoch+1)

        classes = [_dir.name for _dir in Path(DATASET_ROOT_TEST).glob('*')]
        total_correct = 0
        total = 0
        class_correct = list(0. for i in enumerate(classes))
        class_total = list(0. for i in enumerate(classes))
        with torch.no_grad():
            for inputs, labels in test_data_loader:
                    inputs = Variable(inputs.cuda(CUDA_DEVICES))
                    labels = Variable(labels.cuda(CUDA_DEVICES))
                    outputs = model(inputs)
                    _, predicted = torch.max(outputs.data, 1)
                    loss_test = criterion(outputs, labels)
                    # test
                    testing_loss += loss_test.item() * inputs.size(0)
                    testing_corrects += torch.sum(predicted == labels.data)
                    # totoal
                    total += labels.size(0)
                    total_correct += (predicted == labels).sum().item()
                    c = (predicted == labels).squeeze()
                    # batch size
                    for i in range(labels.size(0)):
                        label =labels[i]
                        class_correct[label] += c[i].item()
                        class_total[label] += 1
                
        testing_loss = testing_loss / len(test_set)
        testing_acc =testing_corrects.double() /len(test_set)

        test_loss_list.append(testing_loss)
        test_acc_list.append(testing_acc)
        test_epoch_list.append(epoch+1)


        #print(training_acc.type())
        #print(f'training_corrects: {training_corrects}\tlen(train_set):{len(train_set)}\n')
        print(f'Training loss: {training_loss:.4f}\taccuracy: {training_acc:.4f}\n')
        
        
        if training_acc > best_acc:
                best_acc = training_acc
                best_model_params = copy.deepcopy(model.state_dict())

model.load_state_dict(best_model_params)
# Out:
# Epoch: 1/20
# -----------
# Training loss: 5.2820	accuracy: 0.0083
#
# Epoch: 2/20
# -----------
# Training loss: 5.1178	accuracy: 0.0179
#
# Epoch: 3/20
# -----------
# Training loss: 4.9952	accuracy: 0.0250
#
# Epoch: 4/20
# -----------
# Training loss: 4.8271	accuracy: 0.0365
#
# Epoch: 5/20
# -----------
# Training loss: 4.6023	accuracy: 0.0502
#
# Epoch: 6/20
# -----------
# Training loss: 4.4351	accuracy: 0.0619
#
# Epoch: 7/20
# -----------
# Training loss: 4.2315	accuracy: 0.0766
#
# Epoch: 8/20
# -----------
# Training loss: 4.0082	accuracy: 0.1030
#
# Epoch: 9/20
# -----------
# Training loss: 3.7658	accuracy: 0.1331
#
# Epoch: 10/20
# ------------
# Training loss: 3.4787	accuracy: 0.1798
#
# Epoch: 11/20
# ------------
# Training loss: 3.2043	accuracy: 0.2295
#
# Epoch: 12/20
# ------------
# Training loss: 2.9353	accuracy: 0.2819
#
# Epoch: 13/20
# ------------
# Training loss: 2.7111	accuracy: 0.3306
#
# Epoch: 14/20
# ------------
# Training loss: 2.4813	accuracy: 0.3725
#
# Epoch: 15/20
# ------------
# Training loss: 2.2715	accuracy: 0.4220
#
# Epoch: 16/20
# ------------
# Training loss: 2.1409	accuracy: 0.4537
#
# Epoch: 17/20
# ------------
# Training loss: 2.0040	accuracy: 0.4899
#
# Epoch: 18/20
# ------------
# Training loss: 1.8515	accuracy: 0.5189
#
# Epoch: 19/20
# ------------
# Training loss: 1.7018	accuracy: 0.5596
#
# Epoch: 20/20
# ------------
# Training loss: 1.6376	accuracy: 0.5736

# %%
#model.load_state_dict(best_model_params)
#torch.save(model, f'without,model-{best_acc:.02f}-best_train_acc.pth')

# %%
plt.plot(epoch_list, train_loss_list, label='train')
plt.plot(test_epoch_list, test_loss_list, label='test')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend(['train','test'], loc='upper right')
plt.savefig("loss.png",dpi=250,format="png")
plt.tight_layout()
plt.show()

plt.plot(epoch_list, train_acc_list, label='train')
plt.plot(test_epoch_list, test_acc_list, label='test')
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.legend(['train','test'], loc='upper right')
plt.savefig("accuracy.png",dpi=250,format="png")
plt.tight_layout()
plt.show()

# %%
print('Accuracy on the ALL test images: %d %%'
      % (100 * total_correct / total))

for i, c in enumerate(classes):
    print('Accuracy of %5s : %2d %%' % (
    c, 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy on the ALL test images: 50 %
# Accuracy of  0149 : 61 %
# Accuracy of  0025 : 46 %
# Accuracy of  0174 : 58 %
# Accuracy of  0151 : 58 %
# Accuracy of  0132 : 51 %
# Accuracy of  0010 : 48 %
# Accuracy of  0122 : 60 %
# Accuracy of  0143 : 55 %
# Accuracy of  0026 : 55 %
# Accuracy of  0146 : 90 %
# Accuracy of  0101 : 38 %
# Accuracy of  0075 : 25 %
# Accuracy of  0121 : 68 %
# Accuracy of  0177 : 47 %
# Accuracy of  0130 : 60 %
# Accuracy of  0067 : 47 %
# Accuracy of  0175 : 53 %
# Accuracy of  0154 : 64 %
# Accuracy of  0079 : 60 %
# Accuracy of  0131 : 71 %
# Accuracy of  0059 : 31 %
# Accuracy of  0169 : 50 %
# Accuracy of  0069 : 57 %
# Accuracy of  0072 : 28 %
# Accuracy of  0128 : 64 %
# Accuracy of  0124 : 46 %
# Accuracy of  0009 : 14 %
# Accuracy of  0032 : 56 %
# Accuracy of  0063 : 50 %
# Accuracy of  0171 : 41 %
# Accuracy of  0024 : 40 %
# Accuracy of  0152 : 57 %
# Accuracy of  0189 : 55 %
# Accuracy of  0044 : 59 %
# Accuracy of  0029 : 52 %
# Accuracy of  0127 : 41 %
# Accuracy of  0136 :  8 %
# Accuracy of  0163 : 61 %
# Accuracy of  0061 : 48 %
# Accuracy of  0047 : 34 %
# Accuracy of  0097 : 61 %
# Accuracy of  0092 : 45 %
# Accuracy of  0091 : 30 %
# Accuracy of  0006 : 52 %
# Accuracy of  0065 : 44 %
# Accuracy of  0001 : 70 %
# Accuracy of  0098 : 60 %
# Accuracy of  0051 : 62 %
# Accuracy of  0156 : 33 %
# Accuracy of  0027 : 54 %
# Accuracy of  0106 : 83 %
# Accuracy of  0035 : 39 %
# Accuracy of  0003 : 50 %
# Accuracy of  0108 : 61 %
# Accuracy of  0113 : 71 %
# Accuracy of  0054 : 42 %
# Accuracy of  0062 : 48 %
# Accuracy of  0150 : 52 %
# Accuracy of  0102 : 69 %
# Accuracy of  0076 : 58 %
# Accuracy of  0167 : 47 %
# Accuracy of  0042 : 23 %
# Accuracy of  0033 : 38 %
# Accuracy of  0157 : 75 %
# Accuracy of  0145 : 43 %
# Accuracy of  0048 : 47 %
# Accuracy of  0176 : 52 %
# Accuracy of  0186 : 69 %
# Accuracy of  0135 : 58 %
# Accuracy of  0060 : 80 %
# Accuracy of  0052 : 53 %
# Accuracy of  0160 : 65 %
# Accuracy of  0195 : 39 %
# Accuracy of  0058 : 33 %
# Accuracy of  0066 : 46 %
# Accuracy of  0103 : 25 %
# Accuracy of  0181 : 44 %
# Accuracy of  0056 : 34 %
# Accuracy of  0085 : 86 %
# Accuracy of  0050 : 57 %
# Accuracy of  0158 : 72 %
# Accuracy of  0015 : 41 %
# Accuracy of  0184 : 40 %
# Accuracy of  0142 : 84 %
# Accuracy of  0119 : 72 %
# Accuracy of  0096 : 42 %
# Accuracy of  0190 : 51 %
# Accuracy of  0081 : 71 %
# Accuracy of  0088 : 69 %
# Accuracy of  0144 : 45 %
# Accuracy of  0188 : 51 %
# Accuracy of  0178 : 63 %
# Accuracy of  0087 : 40 %
# Accuracy of  0074 : 27 %
# Accuracy of  0012 : 36 %
# Accuracy of  0007 : 53 %
# Accuracy of  0161 : 75 %
# Accuracy of  0086 : 61 %
# Accuracy of  0166 : 41 %
# Accuracy of  0057 : 51 %
# Accuracy of  0173 : 53 %
# Accuracy of  0040 : 58 %
# Accuracy of  0168 : 69 %
# Accuracy of  0137 : 72 %
# Accuracy of  0070 : 76 %
# Accuracy of  0109 : 43 %
# Accuracy of  0021 : 38 %
# Accuracy of  0043 : 43 %
# Accuracy of  0034 : 52 %
# Accuracy of  0162 : 68 %
# Accuracy of  0120 : 19 %
# Accuracy of  0039 : 50 %
# Accuracy of  0104 : 40 %
# Accuracy of  0133 : 42 %
# Accuracy of  0045 : 25 %
# Accuracy of  0153 : 50 %
# Accuracy of  0002 : 43 %
# Accuracy of  0134 : 82 %
# Accuracy of  0089 : 64 %
# Accuracy of  0037 : 47 %
# Accuracy of  0183 : 57 %
# Accuracy of  0116 : 45 %
# Accuracy of  0138 : 35 %
# Accuracy of  0147 : 34 %
# Accuracy of  0019 : 35 %
# Accuracy of  0155 : 64 %
# Accuracy of  0020 : 50 %
# Accuracy of  0023 : 10 %
# Accuracy of  0068 : 27 %
# Accuracy of  0011 : 81 %
# Accuracy of  0041 : 42 %
# Accuracy of  0140 : 33 %
# Accuracy of  0141 : 52 %
# Accuracy of  0090 : 19 %
# Accuracy of  0187 : 32 %
# Accuracy of  0055 : 66 %
# Accuracy of  0105 : 69 %
# Accuracy of  0064 :  0 %
# Accuracy of  0005 : 52 %
# Accuracy of  0182 : 45 %
# Accuracy of  0172 : 66 %
# Accuracy of  0100 : 72 %
# Accuracy of  0110 : 46 %
# Accuracy of  0080 : 62 %
# Accuracy of  0094 : 67 %
# Accuracy of  0030 :  2 %
# Accuracy of  0185 : 44 %
# Accuracy of  0053 : 79 %
# Accuracy of  0114 : 42 %
# Accuracy of  0008 : 26 %
# Accuracy of  0049 : 67 %
# Accuracy of  0191 : 56 %
# Accuracy of  0111 : 47 %
# Accuracy of  0179 : 48 %
# Accuracy of  0192 : 61 %
# Accuracy of  0126 : 73 %
# Accuracy of  0038 : 37 %
# Accuracy of  0082 : 66 %
# Accuracy of  0028 : 56 %
# Accuracy of  0013 : 65 %
# Accuracy of  0194 : 57 %
# Accuracy of  0129 :  7 %
# Accuracy of  0014 : 34 %
# Accuracy of  0099 : 66 %
# Accuracy of  0115 : 42 %
# Accuracy of  0123 : 75 %
# Accuracy of  0112 : 40 %
# Accuracy of  0077 : 47 %
# Accuracy of  0084 : 64 %
# Accuracy of  0196 : 35 %
# Accuracy of  0046 : 25 %
# Accuracy of  0125 : 41 %
# Accuracy of  0018 : 30 %
# Accuracy of  0117 : 59 %
# Accuracy of  0073 : 33 %
# Accuracy of  0016 : 37 %
# Accuracy of  0164 : 53 %
# Accuracy of  0165 : 59 %
# Accuracy of  0036 : 68 %
# Accuracy of  0180 : 35 %
# Accuracy of  0031 : 31 %
# Accuracy of  0193 : 38 %
# Accuracy of  0170 : 45 %
# Accuracy of  0022 :  4 %
# Accuracy of  0118 : 78 %
# Accuracy of  0083 : 32 %
# Accuracy of  0004 : 64 %
# Accuracy of  0148 : 35 %
# Accuracy of  0095 : 71 %
# Accuracy of  0159 : 66 %
# Accuracy of  0078 : 64 %
# Accuracy of  0139 : 69 %
# Accuracy of  0107 : 36 %
# Accuracy of  0071 : 22 %
# Accuracy of  0093 : 64 %
# Accuracy of  0017 : 22 %
