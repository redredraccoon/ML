# %%
import torch
import torch.nn as nn
#from models import VGG16
import torchvision.models as models
from dataset import IMAGE_Dataset
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from pathlib import Path
import copy
import matplotlib.pyplot as plt

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
##REPRODUCIBILITY
torch.manual_seed(123)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
CUDA_DEVICES = 0
DATASET_ROOT = './new/train'
DATASET_ROOT_TEST = './new/test'

# %%
data_transform = transforms.Compose([
		transforms.Resize((224,224)),
		transforms.ToTensor(),
		transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
	])
#print(DATASET_ROOT)
#train_load
train_set = IMAGE_Dataset(Path(DATASET_ROOT), data_transform)
train_data_loader = DataLoader(dataset=train_set, batch_size=32, shuffle=True, num_workers=1)
#test_load
test_set = IMAGE_Dataset(Path(DATASET_ROOT_TEST), data_transform)
test_data_loader = DataLoader(dataset=test_set, batch_size=32, shuffle=True, num_workers=1)

print(train_set.num_classes)
# Out:
# 196

# %%
model = models.resnet101(pretrained=False)

# %%
fc_features = model.fc.in_features
model.fc = nn.Linear(fc_features,196)

model.fc
# Out:
# Linear(in_features=2048, out_features=196, bias=True)

# %%
#model = VGG16(num_classes=train_set.num_classes)
model = model.cuda(CUDA_DEVICES)
model.train()

best_model_params = copy.deepcopy(model.state_dict())
best_acc = 0.0
num_epochs = 10
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params=model.parameters(), lr=0.01, momentum=0.9)

# %%
train_loss_list = [] 
train_acc_list = [] 
epoch_list = []

test_loss_list = [] 
test_acc_list = [] 
test_epoch_list = []

# %%
for epoch in range(num_epochs):
        print(f'Epoch: {epoch + 1}/{num_epochs}')
        print('-' * len(f'Epoch: {epoch + 1}/{num_epochs}'))

        training_loss = 0.0
        training_corrects = 0

        testing_loss = 0.0
        testing_corrects = 0

        for i, (inputs, labels) in enumerate(train_data_loader):
                inputs = Variable(inputs.cuda(CUDA_DEVICES))
                labels = Variable(labels.cuda(CUDA_DEVICES))			

                optimizer.zero_grad()

                outputs = model(inputs)
                _, preds = torch.max(outputs.data, 1)
                loss = criterion(outputs, labels)

                loss.backward()
                optimizer.step()

                training_loss += loss.item() * inputs.size(0)
                #revise loss.data[0]-->loss.item()
                training_corrects += torch.sum(preds == labels.data)
                #print(f'training_corrects: {training_corrects}')

        training_loss = training_loss / len(train_set)
        training_acc =training_corrects.double() /len(train_set)

        train_loss_list.append(training_loss)
        train_acc_list.append(training_acc)
        epoch_list.append(epoch+1)

        classes = [_dir.name for _dir in Path(DATASET_ROOT_TEST).glob('*')]
        total_correct = 0
        total = 0
        class_correct = list(0. for i in enumerate(classes))
        class_total = list(0. for i in enumerate(classes))
        with torch.no_grad():
            for inputs, labels in test_data_loader:
                    inputs = Variable(inputs.cuda(CUDA_DEVICES))
                    labels = Variable(labels.cuda(CUDA_DEVICES))
                    outputs = model(inputs)
                    _, predicted = torch.max(outputs.data, 1)
                    loss_test = criterion(outputs, labels)
                    # test
                    testing_loss += loss_test.item() * inputs.size(0)
                    testing_corrects += torch.sum(predicted == labels.data)
                    # totoal
                    total += labels.size(0)
                    total_correct += (predicted == labels).sum().item()
                    c = (predicted == labels).squeeze()
                    # batch size
                    for i in range(labels.size(0)):
                        label =labels[i]
                        class_correct[label] += c[i].item()
                        class_total[label] += 1
                
        testing_loss = testing_loss / len(test_set)
        testing_acc =testing_corrects.double() /len(test_set)

        test_loss_list.append(testing_loss)
        test_acc_list.append(testing_acc)
        test_epoch_list.append(epoch+1)


        #print(training_acc.type())
        #print(f'training_corrects: {training_corrects}\tlen(train_set):{len(train_set)}\n')
        print(f'Training loss: {training_loss:.4f}\taccuracy: {training_acc:.4f}\n')
        
        
        if training_acc > best_acc:
                best_acc = training_acc
                best_model_params = copy.deepcopy(model.state_dict())

model.load_state_dict(best_model_params)
# Out:
# Epoch: 1/10
# -----------
# Training loss: 5.6193	accuracy: 0.0058
#
# Epoch: 2/10
# -----------
# Training loss: 5.2792	accuracy: 0.0090
#
# Epoch: 3/10
# -----------
# Training loss: 5.2001	accuracy: 0.0112
#
# Epoch: 4/10
# -----------
# Training loss: 5.1372	accuracy: 0.0153
#
# Epoch: 5/10
# -----------
# Training loss: 5.0687	accuracy: 0.0192
#
# Epoch: 6/10
# -----------
# Training loss: 5.0144	accuracy: 0.0177
#
# Epoch: 7/10
# -----------
# Training loss: 4.9518	accuracy: 0.0220
#
# Epoch: 8/10
# -----------
# Training loss: 4.8684	accuracy: 0.0287
#
# Epoch: 9/10
# -----------
# Training loss: 4.7571	accuracy: 0.0343
#
# Epoch: 10/10
# ------------
# Training loss: 4.5983	accuracy: 0.0437

# %%
#model.load_state_dict(best_model_params)
#torch.save(model, f'without,model-{best_acc:.02f}-best_train_acc.pth')

# %%
plt.plot(epoch_list, train_loss_list, label='train')
plt.plot(test_epoch_list, test_loss_list, label='test')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend(['train','test'], loc='upper right')
plt.savefig("loss.png",dpi=250,format="png")
plt.tight_layout()
plt.show()

plt.plot(epoch_list, train_acc_list, label='train')
plt.plot(test_epoch_list, test_acc_list, label='test')
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.legend(['train','test'], loc='upper right')
plt.savefig("accuracy.png",dpi=250,format="png")
plt.tight_layout()
plt.show()

# %%
print('Accuracy on the ALL test images: %d %%'
      % (100 * total_correct / total))

for i, c in enumerate(classes):
    print('Accuracy of %5s : %2d %%' % (
    c, 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy on the ALL test images: 4 %
# Accuracy of  0149 :  0 %
# Accuracy of  0025 :  0 %
# Accuracy of  0174 : 26 %
# Accuracy of  0151 :  0 %
# Accuracy of  0132 :  0 %
# Accuracy of  0010 :  0 %
# Accuracy of  0122 :  0 %
# Accuracy of  0143 :  0 %
# Accuracy of  0026 :  0 %
# Accuracy of  0146 :  0 %
# Accuracy of  0101 :  4 %
# Accuracy of  0075 :  0 %
# Accuracy of  0121 :  2 %
# Accuracy of  0177 :  0 %
# Accuracy of  0130 :  0 %
# Accuracy of  0067 :  0 %
# Accuracy of  0175 :  0 %
# Accuracy of  0154 :  4 %
# Accuracy of  0079 :  4 %
# Accuracy of  0131 :  0 %
# Accuracy of  0059 :  0 %
# Accuracy of  0169 :  0 %
# Accuracy of  0069 :  5 %
# Accuracy of  0072 :  0 %
# Accuracy of  0128 :  2 %
# Accuracy of  0124 : 10 %
# Accuracy of  0009 :  0 %
# Accuracy of  0032 :  0 %
# Accuracy of  0063 :  0 %
# Accuracy of  0171 :  0 %
# Accuracy of  0024 :  0 %
# Accuracy of  0152 : 14 %
# Accuracy of  0189 : 27 %
# Accuracy of  0044 :  2 %
# Accuracy of  0029 :  7 %
# Accuracy of  0127 :  7 %
# Accuracy of  0136 :  0 %
# Accuracy of  0163 :  0 %
# Accuracy of  0061 :  4 %
# Accuracy of  0047 :  0 %
# Accuracy of  0097 :  0 %
# Accuracy of  0092 :  5 %
# Accuracy of  0091 :  0 %
# Accuracy of  0006 :  2 %
# Accuracy of  0065 :  0 %
# Accuracy of  0001 : 56 %
# Accuracy of  0098 :  0 %
# Accuracy of  0051 :  0 %
# Accuracy of  0156 :  2 %
# Accuracy of  0027 :  2 %
# Accuracy of  0106 :  0 %
# Accuracy of  0035 :  0 %
# Accuracy of  0003 :  0 %
# Accuracy of  0108 :  9 %
# Accuracy of  0113 :  0 %
# Accuracy of  0054 :  0 %
# Accuracy of  0062 :  0 %
# Accuracy of  0150 :  0 %
# Accuracy of  0102 :  0 %
# Accuracy of  0076 :  4 %
# Accuracy of  0167 :  0 %
# Accuracy of  0042 :  0 %
# Accuracy of  0033 :  4 %
# Accuracy of  0157 : 61 %
# Accuracy of  0145 :  9 %
# Accuracy of  0048 :  2 %
# Accuracy of  0176 :  0 %
# Accuracy of  0186 :  5 %
# Accuracy of  0135 :  2 %
# Accuracy of  0060 :  0 %
# Accuracy of  0052 :  0 %
# Accuracy of  0160 : 68 %
# Accuracy of  0195 :  0 %
# Accuracy of  0058 :  0 %
# Accuracy of  0066 :  9 %
# Accuracy of  0103 :  2 %
# Accuracy of  0181 :  0 %
# Accuracy of  0056 :  0 %
# Accuracy of  0085 :  0 %
# Accuracy of  0050 :  0 %
# Accuracy of  0158 :  0 %
# Accuracy of  0015 :  0 %
# Accuracy of  0184 :  0 %
# Accuracy of  0142 :  0 %
# Accuracy of  0119 : 16 %
# Accuracy of  0096 :  0 %
# Accuracy of  0190 :  0 %
# Accuracy of  0081 :  0 %
# Accuracy of  0088 :  0 %
# Accuracy of  0144 :  0 %
# Accuracy of  0188 :  0 %
# Accuracy of  0178 :  0 %
# Accuracy of  0087 : 40 %
# Accuracy of  0074 :  6 %
# Accuracy of  0012 :  0 %
# Accuracy of  0007 :  0 %
# Accuracy of  0161 :  0 %
# Accuracy of  0086 :  0 %
# Accuracy of  0166 :  0 %
# Accuracy of  0057 :  0 %
# Accuracy of  0173 : 41 %
# Accuracy of  0040 : 25 %
# Accuracy of  0168 : 47 %
# Accuracy of  0137 :  2 %
# Accuracy of  0070 :  0 %
# Accuracy of  0109 :  0 %
# Accuracy of  0021 :  7 %
# Accuracy of  0043 :  0 %
# Accuracy of  0034 :  2 %
# Accuracy of  0162 :  0 %
# Accuracy of  0120 :  0 %
# Accuracy of  0039 :  0 %
# Accuracy of  0104 :  0 %
# Accuracy of  0133 :  0 %
# Accuracy of  0045 :  0 %
# Accuracy of  0153 : 31 %
# Accuracy of  0002 :  0 %
# Accuracy of  0134 :  0 %
# Accuracy of  0089 :  0 %
# Accuracy of  0037 :  0 %
# Accuracy of  0183 :  0 %
# Accuracy of  0116 :  0 %
# Accuracy of  0138 :  5 %
# Accuracy of  0147 :  0 %
# Accuracy of  0019 :  0 %
# Accuracy of  0155 :  0 %
# Accuracy of  0020 :  2 %
# Accuracy of  0023 :  0 %
# Accuracy of  0068 :  0 %
# Accuracy of  0011 :  0 %
# Accuracy of  0041 :  2 %
# Accuracy of  0140 :  0 %
# Accuracy of  0141 :  0 %
# Accuracy of  0090 :  0 %
# Accuracy of  0187 :  0 %
# Accuracy of  0055 :  0 %
# Accuracy of  0105 :  0 %
# Accuracy of  0064 : 72 %
# Accuracy of  0005 :  0 %
# Accuracy of  0182 :  0 %
# Accuracy of  0172 :  0 %
# Accuracy of  0100 : 21 %
# Accuracy of  0110 :  0 %
# Accuracy of  0080 : 11 %
# Accuracy of  0094 :  0 %
# Accuracy of  0030 :  0 %
# Accuracy of  0185 :  0 %
# Accuracy of  0053 :  0 %
# Accuracy of  0114 :  0 %
# Accuracy of  0008 :  0 %
# Accuracy of  0049 :  0 %
# Accuracy of  0191 :  0 %
# Accuracy of  0111 :  0 %
# Accuracy of  0179 :  0 %
# Accuracy of  0192 :  0 %
# Accuracy of  0126 :  0 %
# Accuracy of  0038 :  0 %
# Accuracy of  0082 : 33 %
# Accuracy of  0028 :  0 %
# Accuracy of  0013 :  0 %
# Accuracy of  0194 :  4 %
# Accuracy of  0129 :  0 %
# Accuracy of  0014 :  0 %
# Accuracy of  0099 : 11 %
# Accuracy of  0115 :  0 %
# Accuracy of  0123 :  0 %
# Accuracy of  0112 :  4 %
# Accuracy of  0077 :  0 %
# Accuracy of  0084 : 14 %
# Accuracy of  0196 :  0 %
# Accuracy of  0046 :  0 %
# Accuracy of  0125 :  0 %
# Accuracy of  0018 :  0 %
# Accuracy of  0117 :  0 %
# Accuracy of  0073 :  0 %
# Accuracy of  0016 :  0 %
# Accuracy of  0164 :  2 %
# Accuracy of  0165 :  0 %
# Accuracy of  0036 :  0 %
# Accuracy of  0180 :  0 %
# Accuracy of  0031 :  6 %
# Accuracy of  0193 :  0 %
# Accuracy of  0170 :  2 %
# Accuracy of  0022 :  0 %
# Accuracy of  0118 :  0 %
# Accuracy of  0083 :  0 %
# Accuracy of  0004 :  0 %
# Accuracy of  0148 :  0 %
# Accuracy of  0095 :  0 %
# Accuracy of  0159 : 11 %
# Accuracy of  0078 :  0 %
# Accuracy of  0139 :  0 %
# Accuracy of  0107 :  0 %
# Accuracy of  0071 :  0 %
# Accuracy of  0093 :  7 %
# Accuracy of  0017 :  0 %
