# %%
import torch
import torch.nn as nn
#from models import VGG16
import torchvision.models as models
from dataset import IMAGE_Dataset
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from pathlib import Path
import copy
import matplotlib.pyplot as plt

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
##REPRODUCIBILITY
torch.manual_seed(123)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
CUDA_DEVICES = 0
DATASET_ROOT = './new/train'
DATASET_ROOT_TEST = './new/test'

# %%
data_transform = transforms.Compose([
		transforms.Resize((224,224)),
		transforms.ToTensor(),
		transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
	])
#print(DATASET_ROOT)
#train_load
train_set = IMAGE_Dataset(Path(DATASET_ROOT), data_transform)
train_data_loader = DataLoader(dataset=train_set, batch_size=32, shuffle=True, num_workers=1)
#test_load
test_set = IMAGE_Dataset(Path(DATASET_ROOT_TEST), data_transform)
test_data_loader = DataLoader(dataset=test_set, batch_size=32, shuffle=True, num_workers=1)

print(train_set.num_classes)
# Out:
# 196

# %%
model = models.resnet101(pretrained=True)

# %%
fc_features = model.fc.in_features
model.fc = nn.Linear(fc_features,196)

model.fc
# Out:
# Linear(in_features=2048, out_features=196, bias=True)

# %%
#model = VGG16(num_classes=train_set.num_classes)
model = model.cuda(CUDA_DEVICES)
model.train()

best_model_params = copy.deepcopy(model.state_dict())
best_acc = 0.0
num_epochs = 20
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model.parameters(), lr=0.001)
#optimizer = torch.optim.SGD(params=model.parameters(), lr=0.001, momentum=0.9)

# %%
train_loss_list = [] 
train_acc_list = [] 
epoch_list = []

test_loss_list = [] 
test_acc_list = [] 
test_epoch_list = []

# %%
for epoch in range(num_epochs):
        print(f'Epoch: {epoch + 1}/{num_epochs}')
        print('-' * len(f'Epoch: {epoch + 1}/{num_epochs}'))

        training_loss = 0.0
        training_corrects = 0

        testing_loss = 0.0
        testing_corrects = 0

        for i, (inputs, labels) in enumerate(train_data_loader):
                inputs = Variable(inputs.cuda(CUDA_DEVICES))
                labels = Variable(labels.cuda(CUDA_DEVICES))			

                optimizer.zero_grad()

                outputs = model(inputs)
                _, preds = torch.max(outputs.data, 1)
                loss = criterion(outputs, labels)

                loss.backward()
                optimizer.step()

                training_loss += loss.item() * inputs.size(0)
                #revise loss.data[0]-->loss.item()
                training_corrects += torch.sum(preds == labels.data)
                #print(f'training_corrects: {training_corrects}')

        training_loss = training_loss / len(train_set)
        training_acc =training_corrects.double() /len(train_set)

        train_loss_list.append(training_loss)
        train_acc_list.append(training_acc)
        epoch_list.append(epoch+1)

        classes = [_dir.name for _dir in Path(DATASET_ROOT_TEST).glob('*')]
        total_correct = 0
        total = 0
        class_correct = list(0. for i in enumerate(classes))
        class_total = list(0. for i in enumerate(classes))
        with torch.no_grad():
            for inputs, labels in test_data_loader:
                    inputs = Variable(inputs.cuda(CUDA_DEVICES))
                    labels = Variable(labels.cuda(CUDA_DEVICES))
                    outputs = model(inputs)
                    _, predicted = torch.max(outputs.data, 1)
                    loss_test = criterion(outputs, labels)
                    # test
                    testing_loss += loss_test.item() * inputs.size(0)
                    testing_corrects += torch.sum(predicted == labels.data)
                    # totoal
                    total += labels.size(0)
                    total_correct += (predicted == labels).sum().item()
                    c = (predicted == labels).squeeze()
                    # batch size
                    for i in range(labels.size(0)):
                        label =labels[i]
                        class_correct[label] += c[i].item()
                        class_total[label] += 1
                
        testing_loss = testing_loss / len(test_set)
        testing_acc =testing_corrects.double() /len(test_set)

        test_loss_list.append(testing_loss)
        test_acc_list.append(testing_acc)
        test_epoch_list.append(epoch+1)


        #print(training_acc.type())
        #print(f'training_corrects: {training_corrects}\tlen(train_set):{len(train_set)}\n')
        print(f'Training loss: {training_loss:.4f}\taccuracy: {training_acc:.4f}\n')
        
        
        if training_acc > best_acc:
                best_acc = training_acc
                best_model_params = copy.deepcopy(model.state_dict())

model.load_state_dict(best_model_params)
# Out:
# Epoch: 1/20
# -----------
# Training loss: 5.2883	accuracy: 0.0066
#
# Epoch: 2/20
# -----------
# Training loss: 5.1402	accuracy: 0.0153
#
# Epoch: 3/20
# -----------
# Training loss: 4.9677	accuracy: 0.0212
#
# Epoch: 4/20
# -----------
# Training loss: 4.6757	accuracy: 0.0373
#
# Epoch: 5/20
# -----------
# Training loss: 4.3223	accuracy: 0.0631
#
# Epoch: 6/20
# -----------
# Training loss: 3.9395	accuracy: 0.0947
#
# Epoch: 7/20
# -----------
# Training loss: 3.4205	accuracy: 0.1611
#
# Epoch: 8/20
# -----------
# Training loss: 2.8035	accuracy: 0.2692
#
# Epoch: 9/20
# -----------
# Training loss: 2.2481	accuracy: 0.3875
#
# Epoch: 10/20
# ------------
# Training loss: 1.7114	accuracy: 0.5054
#
# Epoch: 11/20
# ------------
# Training loss: 1.3051	accuracy: 0.6160
#
# Epoch: 12/20
# ------------
# Training loss: 1.0049	accuracy: 0.6973
#
# Epoch: 13/20
# ------------
# Training loss: 0.7340	accuracy: 0.7696
#
# Epoch: 14/20
# ------------
# Training loss: 0.5333	accuracy: 0.8384
#
# Epoch: 15/20
# ------------
# Training loss: 0.4218	accuracy: 0.8679
#
# Epoch: 16/20
# ------------
# Training loss: 0.3267	accuracy: 0.9009
#
# Epoch: 17/20
# ------------
# Training loss: 0.2535	accuracy: 0.9260
#
# Epoch: 18/20
# ------------
# Training loss: 0.2410	accuracy: 0.9264
#
# Epoch: 19/20
# ------------
# Training loss: 0.1609	accuracy: 0.9559
#
# Epoch: 20/20
# ------------
# Training loss: 0.1617	accuracy: 0.9500

# %%
#model.load_state_dict(best_model_params)
#torch.save(model, f'without,model-{best_acc:.02f}-best_train_acc.pth')

# %%
plt.plot(epoch_list, train_loss_list, label='train')
plt.plot(test_epoch_list, test_loss_list, label='test')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend(['train','test'], loc='upper right')
plt.savefig("loss.png",dpi=250,format="png")
plt.tight_layout()
plt.show()

plt.plot(epoch_list, train_acc_list, label='train')
plt.plot(test_epoch_list, test_acc_list, label='test')
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.legend(['train','test'], loc='upper right')
plt.savefig("accuracy.png",dpi=250,format="png")
plt.tight_layout()
plt.show()

# %%
print('Accuracy on the ALL test images: %d %%'
      % (100 * total_correct / total))

for i, c in enumerate(classes):
    print('Accuracy of %5s : %2d %%' % (
    c, 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy on the ALL test images: 54 %
# Accuracy of  0149 : 64 %
# Accuracy of  0025 : 74 %
# Accuracy of  0174 : 51 %
# Accuracy of  0151 : 55 %
# Accuracy of  0132 : 67 %
# Accuracy of  0010 : 60 %
# Accuracy of  0122 : 80 %
# Accuracy of  0143 : 65 %
# Accuracy of  0026 : 32 %
# Accuracy of  0146 : 72 %
# Accuracy of  0101 : 61 %
# Accuracy of  0075 : 36 %
# Accuracy of  0121 : 68 %
# Accuracy of  0177 : 31 %
# Accuracy of  0130 : 51 %
# Accuracy of  0067 : 47 %
# Accuracy of  0175 : 73 %
# Accuracy of  0154 : 73 %
# Accuracy of  0079 : 45 %
# Accuracy of  0131 : 40 %
# Accuracy of  0059 : 47 %
# Accuracy of  0169 : 60 %
# Accuracy of  0069 : 31 %
# Accuracy of  0072 : 40 %
# Accuracy of  0128 : 48 %
# Accuracy of  0124 : 33 %
# Accuracy of  0009 : 19 %
# Accuracy of  0032 : 58 %
# Accuracy of  0063 : 38 %
# Accuracy of  0171 : 58 %
# Accuracy of  0024 : 33 %
# Accuracy of  0152 : 48 %
# Accuracy of  0189 : 92 %
# Accuracy of  0044 : 29 %
# Accuracy of  0029 : 57 %
# Accuracy of  0127 : 68 %
# Accuracy of  0136 : 62 %
# Accuracy of  0163 : 52 %
# Accuracy of  0061 : 37 %
# Accuracy of  0047 : 42 %
# Accuracy of  0097 : 40 %
# Accuracy of  0092 : 55 %
# Accuracy of  0091 : 41 %
# Accuracy of  0006 : 72 %
# Accuracy of  0065 : 66 %
# Accuracy of  0001 : 43 %
# Accuracy of  0098 : 54 %
# Accuracy of  0051 : 69 %
# Accuracy of  0156 : 43 %
# Accuracy of  0027 : 51 %
# Accuracy of  0106 : 61 %
# Accuracy of  0035 : 65 %
# Accuracy of  0003 : 31 %
# Accuracy of  0108 : 40 %
# Accuracy of  0113 : 57 %
# Accuracy of  0054 : 37 %
# Accuracy of  0062 : 37 %
# Accuracy of  0150 : 72 %
# Accuracy of  0102 : 53 %
# Accuracy of  0076 : 76 %
# Accuracy of  0167 : 68 %
# Accuracy of  0042 : 11 %
# Accuracy of  0033 : 64 %
# Accuracy of  0157 : 83 %
# Accuracy of  0145 : 59 %
# Accuracy of  0048 : 57 %
# Accuracy of  0176 : 76 %
# Accuracy of  0186 : 56 %
# Accuracy of  0135 : 72 %
# Accuracy of  0060 : 69 %
# Accuracy of  0052 : 68 %
# Accuracy of  0160 : 79 %
# Accuracy of  0195 : 58 %
# Accuracy of  0058 : 46 %
# Accuracy of  0066 : 39 %
# Accuracy of  0103 : 64 %
# Accuracy of  0181 : 34 %
# Accuracy of  0056 : 41 %
# Accuracy of  0085 : 88 %
# Accuracy of  0050 : 76 %
# Accuracy of  0158 : 31 %
# Accuracy of  0015 : 53 %
# Accuracy of  0184 : 37 %
# Accuracy of  0142 : 65 %
# Accuracy of  0119 : 77 %
# Accuracy of  0096 : 30 %
# Accuracy of  0190 : 44 %
# Accuracy of  0081 : 82 %
# Accuracy of  0088 : 30 %
# Accuracy of  0144 : 63 %
# Accuracy of  0188 : 62 %
# Accuracy of  0178 : 68 %
# Accuracy of  0087 : 47 %
# Accuracy of  0074 : 46 %
# Accuracy of  0012 : 55 %
# Accuracy of  0007 : 66 %
# Accuracy of  0161 : 77 %
# Accuracy of  0086 : 73 %
# Accuracy of  0166 : 82 %
# Accuracy of  0057 : 64 %
# Accuracy of  0173 : 48 %
# Accuracy of  0040 : 61 %
# Accuracy of  0168 : 85 %
# Accuracy of  0137 : 79 %
# Accuracy of  0070 : 64 %
# Accuracy of  0109 : 90 %
# Accuracy of  0021 : 42 %
# Accuracy of  0043 : 82 %
# Accuracy of  0034 : 29 %
# Accuracy of  0162 : 66 %
# Accuracy of  0120 : 52 %
# Accuracy of  0039 : 41 %
# Accuracy of  0104 :  9 %
# Accuracy of  0133 : 54 %
# Accuracy of  0045 : 65 %
# Accuracy of  0153 : 81 %
# Accuracy of  0002 : 40 %
# Accuracy of  0134 : 67 %
# Accuracy of  0089 : 51 %
# Accuracy of  0037 : 31 %
# Accuracy of  0183 : 64 %
# Accuracy of  0116 : 64 %
# Accuracy of  0138 : 69 %
# Accuracy of  0147 : 61 %
# Accuracy of  0019 : 12 %
# Accuracy of  0155 : 16 %
# Accuracy of  0020 : 52 %
# Accuracy of  0023 : 12 %
# Accuracy of  0068 : 40 %
# Accuracy of  0011 : 68 %
# Accuracy of  0041 : 91 %
# Accuracy of  0140 : 50 %
# Accuracy of  0141 : 67 %
# Accuracy of  0090 : 46 %
# Accuracy of  0187 : 51 %
# Accuracy of  0055 : 46 %
# Accuracy of  0105 : 60 %
# Accuracy of  0064 : 34 %
# Accuracy of  0005 : 60 %
# Accuracy of  0182 : 47 %
# Accuracy of  0172 : 57 %
# Accuracy of  0100 : 63 %
# Accuracy of  0110 : 65 %
# Accuracy of  0080 : 74 %
# Accuracy of  0094 : 83 %
# Accuracy of  0030 : 53 %
# Accuracy of  0185 : 52 %
# Accuracy of  0053 : 59 %
# Accuracy of  0114 : 51 %
# Accuracy of  0008 : 42 %
# Accuracy of  0049 : 70 %
# Accuracy of  0191 : 56 %
# Accuracy of  0111 : 64 %
# Accuracy of  0179 : 40 %
# Accuracy of  0192 : 59 %
# Accuracy of  0126 : 59 %
# Accuracy of  0038 : 52 %
# Accuracy of  0082 : 48 %
# Accuracy of  0028 : 75 %
# Accuracy of  0013 : 75 %
# Accuracy of  0194 : 64 %
# Accuracy of  0129 : 18 %
# Accuracy of  0014 : 36 %
# Accuracy of  0099 : 66 %
# Accuracy of  0115 : 46 %
# Accuracy of  0123 : 53 %
# Accuracy of  0112 : 44 %
# Accuracy of  0077 : 50 %
# Accuracy of  0084 :  9 %
# Accuracy of  0196 : 52 %
# Accuracy of  0046 : 65 %
# Accuracy of  0125 : 62 %
# Accuracy of  0018 : 30 %
# Accuracy of  0117 : 66 %
# Accuracy of  0073 : 51 %
# Accuracy of  0016 : 27 %
# Accuracy of  0164 : 53 %
# Accuracy of  0165 : 38 %
# Accuracy of  0036 : 26 %
# Accuracy of  0180 : 19 %
# Accuracy of  0031 : 52 %
# Accuracy of  0193 : 40 %
# Accuracy of  0170 : 68 %
# Accuracy of  0022 : 50 %
# Accuracy of  0118 : 70 %
# Accuracy of  0083 : 47 %
# Accuracy of  0004 : 35 %
# Accuracy of  0148 : 75 %
# Accuracy of  0095 : 77 %
# Accuracy of  0159 : 38 %
# Accuracy of  0078 : 64 %
# Accuracy of  0139 : 69 %
# Accuracy of  0107 : 72 %
# Accuracy of  0071 :  8 %
# Accuracy of  0093 : 66 %
# Accuracy of  0017 : 47 %
