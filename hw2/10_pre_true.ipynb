# %%
import torch
import torch.nn as nn
#from models import VGG16
import torchvision.models as models
from dataset import IMAGE_Dataset
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from pathlib import Path
import copy
import matplotlib.pyplot as plt

##REPRODUCIBILITY
torch.manual_seed(123)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
CUDA_DEVICES = 0
DATASET_ROOT = './new/train'
DATASET_ROOT_TEST = './new/test'

# %%
data_transform = transforms.Compose([
		transforms.Resize((224,224)),
		transforms.ToTensor(),
		transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
	])
#print(DATASET_ROOT)
#train_load
train_set = IMAGE_Dataset(Path(DATASET_ROOT), data_transform)
train_data_loader = DataLoader(dataset=train_set, batch_size=32, shuffle=True, num_workers=1)
#test_load
test_set = IMAGE_Dataset(Path(DATASET_ROOT_TEST), data_transform)
test_data_loader = DataLoader(dataset=test_set, batch_size=32, shuffle=True, num_workers=1)

print(train_set.num_classes)
# Out:
# 196

# %%
model = models.resnet101(pretrained=True)

# %%
fc_features = model.fc.in_features
model.fc = nn.Linear(fc_features,196)

model.fc
# Out:
# Linear(in_features=2048, out_features=196, bias=True)

# %%
#model = VGG16(num_classes=train_set.num_classes)
model = model.cuda(CUDA_DEVICES)
model.train()

best_model_params = copy.deepcopy(model.state_dict())
best_acc = 0.0
num_epochs = 10
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params=model.parameters(), lr=0.01, momentum=0.9)

# %%
train_loss_list = [] 
train_acc_list = [] 
epoch_list = []

test_loss_list = [] 
test_acc_list = [] 
test_epoch_list = []

# %%
for epoch in range(num_epochs):
        print(f'Epoch: {epoch + 1}/{num_epochs}')
        print('-' * len(f'Epoch: {epoch + 1}/{num_epochs}'))

        training_loss = 0.0
        training_corrects = 0

        testing_loss = 0.0
        testing_corrects = 0

        for i, (inputs, labels) in enumerate(train_data_loader):
                inputs = Variable(inputs.cuda(CUDA_DEVICES))
                labels = Variable(labels.cuda(CUDA_DEVICES))			

                optimizer.zero_grad()

                outputs = model(inputs)
                _, preds = torch.max(outputs.data, 1)
                loss = criterion(outputs, labels)

                loss.backward()
                optimizer.step()

                training_loss += loss.item() * inputs.size(0)
                #revise loss.data[0]-->loss.item()
                training_corrects += torch.sum(preds == labels.data)
                #print(f'training_corrects: {training_corrects}')

        training_loss = training_loss / len(train_set)
        training_acc =training_corrects.double() /len(train_set)

        train_loss_list.append(training_loss)
        train_acc_list.append(training_acc)
        epoch_list.append(epoch+1)

        classes = [_dir.name for _dir in Path(DATASET_ROOT_TEST).glob('*')]
        total_correct = 0
        total = 0
        class_correct = list(0. for i in enumerate(classes))
        class_total = list(0. for i in enumerate(classes))
        with torch.no_grad():
            for inputs, labels in test_data_loader:
                    inputs = Variable(inputs.cuda(CUDA_DEVICES))
                    labels = Variable(labels.cuda(CUDA_DEVICES))
                    outputs = model(inputs)
                    _, predicted = torch.max(outputs.data, 1)
                    loss_test = criterion(outputs, labels)
                    # test
                    testing_loss += loss_test.item() * inputs.size(0)
                    testing_corrects += torch.sum(predicted == labels.data)
                    # totoal
                    total += labels.size(0)
                    total_correct += (predicted == labels).sum().item()
                    c = (predicted == labels).squeeze()
                    # batch size
                    for i in range(labels.size(0)):
                        label =labels[i]
                        class_correct[label] += c[i].item()
                        class_total[label] += 1
                
        testing_loss = testing_loss / len(test_set)
        testing_acc =testing_corrects.double() /len(test_set)

        test_loss_list.append(testing_loss)
        test_acc_list.append(testing_acc)
        test_epoch_list.append(epoch+1)


        #print(training_acc.type())
        #print(f'training_corrects: {training_corrects}\tlen(train_set):{len(train_set)}\n')
        print(f'Training loss: {training_loss:.4f}\taccuracy: {training_acc:.4f}\n')
        
        
        if training_acc > best_acc:
                best_acc = training_acc
                best_model_params = copy.deepcopy(model.state_dict())

model.load_state_dict(best_model_params)
# Out:
# Epoch: 1/10
# -----------
# Training loss: 3.2615	accuracy: 0.2722
#
# Epoch: 2/10
# -----------
# Training loss: 1.0163	accuracy: 0.7135
#
# Epoch: 3/10
# -----------
# Training loss: 0.4192	accuracy: 0.8822
#
# Epoch: 4/10
# -----------
# Training loss: 0.1864	accuracy: 0.9489
#
# Epoch: 5/10
# -----------
# Training loss: 0.0768	accuracy: 0.9813
#
# Epoch: 6/10
# -----------
# Training loss: 0.0379	accuracy: 0.9909
#
# Epoch: 7/10
# -----------
# Training loss: 0.0213	accuracy: 0.9961
#
# Epoch: 8/10
# -----------
# Training loss: 0.0169	accuracy: 0.9963
#
# Epoch: 9/10
# -----------
# Training loss: 0.0101	accuracy: 0.9979
#
# Epoch: 10/10
# ------------
# Training loss: 0.0084	accuracy: 0.9979

# %%
#model.load_state_dict(best_model_params)
#torch.save(model, f'without,model-{best_acc:.02f}-best_train_acc.pth')

# %%
plt.plot(epoch_list, train_loss_list, label='train')
plt.plot(test_epoch_list, test_loss_list, label='test')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend(['train','test'], loc='upper right')
plt.savefig("loss.png",dpi=250,format="png")
plt.tight_layout()
plt.show()

plt.plot(epoch_list, train_acc_list, label='train')
plt.plot(test_epoch_list, test_acc_list, label='test')
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.legend(['train','test'], loc='upper right')
plt.savefig("accuracy.png",dpi=250,format="png")
plt.tight_layout()
plt.show()

# %%
print('Accuracy on the ALL test images: %d %%'
      % (100 * total_correct / total))

for i, c in enumerate(classes):
    print('Accuracy of %5s : %2d %%' % (
    c, 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy on the ALL test images: 88 %
# Accuracy of  0149 : 88 %
# Accuracy of  0025 : 92 %
# Accuracy of  0174 : 85 %
# Accuracy of  0151 : 81 %
# Accuracy of  0132 : 97 %
# Accuracy of  0010 : 84 %
# Accuracy of  0122 : 85 %
# Accuracy of  0143 : 92 %
# Accuracy of  0026 : 94 %
# Accuracy of  0146 : 97 %
# Accuracy of  0101 : 90 %
# Accuracy of  0075 : 72 %
# Accuracy of  0121 : 93 %
# Accuracy of  0177 : 90 %
# Accuracy of  0130 : 97 %
# Accuracy of  0067 : 76 %
# Accuracy of  0175 : 86 %
# Accuracy of  0154 : 100 %
# Accuracy of  0079 : 85 %
# Accuracy of  0131 : 90 %
# Accuracy of  0059 : 84 %
# Accuracy of  0169 : 97 %
# Accuracy of  0069 : 68 %
# Accuracy of  0072 : 91 %
# Accuracy of  0128 : 92 %
# Accuracy of  0124 : 92 %
# Accuracy of  0009 : 85 %
# Accuracy of  0032 : 95 %
# Accuracy of  0063 : 95 %
# Accuracy of  0171 : 89 %
# Accuracy of  0024 : 91 %
# Accuracy of  0152 : 85 %
# Accuracy of  0189 : 95 %
# Accuracy of  0044 : 97 %
# Accuracy of  0029 : 92 %
# Accuracy of  0127 : 87 %
# Accuracy of  0136 : 87 %
# Accuracy of  0163 : 97 %
# Accuracy of  0061 : 88 %
# Accuracy of  0047 : 97 %
# Accuracy of  0097 : 88 %
# Accuracy of  0092 : 87 %
# Accuracy of  0091 : 87 %
# Accuracy of  0006 : 97 %
# Accuracy of  0065 : 86 %
# Accuracy of  0001 : 95 %
# Accuracy of  0098 : 86 %
# Accuracy of  0051 : 97 %
# Accuracy of  0156 : 97 %
# Accuracy of  0027 : 94 %
# Accuracy of  0106 : 95 %
# Accuracy of  0035 : 90 %
# Accuracy of  0003 : 86 %
# Accuracy of  0108 : 97 %
# Accuracy of  0113 : 95 %
# Accuracy of  0054 : 77 %
# Accuracy of  0062 : 78 %
# Accuracy of  0150 : 97 %
# Accuracy of  0102 : 97 %
# Accuracy of  0076 : 93 %
# Accuracy of  0167 : 83 %
# Accuracy of  0042 : 79 %
# Accuracy of  0033 : 92 %
# Accuracy of  0157 : 97 %
# Accuracy of  0145 : 95 %
# Accuracy of  0048 : 95 %
# Accuracy of  0176 : 86 %
# Accuracy of  0186 : 89 %
# Accuracy of  0135 : 81 %
# Accuracy of  0060 : 97 %
# Accuracy of  0052 : 100 %
# Accuracy of  0160 : 93 %
# Accuracy of  0195 : 95 %
# Accuracy of  0058 : 88 %
# Accuracy of  0066 : 90 %
# Accuracy of  0103 : 84 %
# Accuracy of  0181 : 84 %
# Accuracy of  0056 : 91 %
# Accuracy of  0085 : 95 %
# Accuracy of  0050 : 92 %
# Accuracy of  0158 : 89 %
# Accuracy of  0015 : 90 %
# Accuracy of  0184 : 65 %
# Accuracy of  0142 : 93 %
# Accuracy of  0119 : 82 %
# Accuracy of  0096 : 88 %
# Accuracy of  0190 : 83 %
# Accuracy of  0081 : 97 %
# Accuracy of  0088 : 84 %
# Accuracy of  0144 : 86 %
# Accuracy of  0188 : 86 %
# Accuracy of  0178 : 95 %
# Accuracy of  0087 : 79 %
# Accuracy of  0074 : 76 %
# Accuracy of  0012 : 88 %
# Accuracy of  0007 : 92 %
# Accuracy of  0161 : 93 %
# Accuracy of  0086 : 85 %
# Accuracy of  0166 : 85 %
# Accuracy of  0057 : 100 %
# Accuracy of  0173 : 90 %
# Accuracy of  0040 : 94 %
# Accuracy of  0168 : 100 %
# Accuracy of  0137 : 95 %
# Accuracy of  0070 : 95 %
# Accuracy of  0109 : 88 %
# Accuracy of  0021 : 69 %
# Accuracy of  0043 : 63 %
# Accuracy of  0034 : 95 %
# Accuracy of  0162 : 97 %
# Accuracy of  0120 : 78 %
# Accuracy of  0039 : 94 %
# Accuracy of  0104 : 85 %
# Accuracy of  0133 : 85 %
# Accuracy of  0045 : 93 %
# Accuracy of  0153 : 90 %
# Accuracy of  0002 : 81 %
# Accuracy of  0134 : 91 %
# Accuracy of  0089 : 91 %
# Accuracy of  0037 : 97 %
# Accuracy of  0183 : 83 %
# Accuracy of  0116 : 100 %
# Accuracy of  0138 : 94 %
# Accuracy of  0147 : 93 %
# Accuracy of  0019 : 55 %
# Accuracy of  0155 : 88 %
# Accuracy of  0020 : 93 %
# Accuracy of  0023 : 76 %
# Accuracy of  0068 : 95 %
# Accuracy of  0011 : 89 %
# Accuracy of  0041 : 97 %
# Accuracy of  0140 : 85 %
# Accuracy of  0141 : 97 %
# Accuracy of  0090 : 75 %
# Accuracy of  0187 : 95 %
# Accuracy of  0055 : 79 %
# Accuracy of  0105 : 95 %
# Accuracy of  0064 : 65 %
# Accuracy of  0005 : 77 %
# Accuracy of  0182 : 84 %
# Accuracy of  0172 : 97 %
# Accuracy of  0100 : 87 %
# Accuracy of  0110 : 97 %
# Accuracy of  0080 : 90 %
# Accuracy of  0094 : 97 %
# Accuracy of  0030 : 85 %
# Accuracy of  0185 : 97 %
# Accuracy of  0053 : 95 %
# Accuracy of  0114 : 95 %
# Accuracy of  0008 : 77 %
# Accuracy of  0049 : 97 %
# Accuracy of  0191 : 100 %
# Accuracy of  0111 : 95 %
# Accuracy of  0179 : 88 %
# Accuracy of  0192 : 100 %
# Accuracy of  0126 : 92 %
# Accuracy of  0038 : 90 %
# Accuracy of  0082 : 93 %
# Accuracy of  0028 : 87 %
# Accuracy of  0013 : 90 %
# Accuracy of  0194 : 95 %
# Accuracy of  0129 : 89 %
# Accuracy of  0014 : 43 %
# Accuracy of  0099 : 96 %
# Accuracy of  0115 : 91 %
# Accuracy of  0123 : 93 %
# Accuracy of  0112 : 86 %
# Accuracy of  0077 : 87 %
# Accuracy of  0084 : 73 %
# Accuracy of  0196 : 97 %
# Accuracy of  0046 : 76 %
# Accuracy of  0125 : 53 %
# Accuracy of  0018 : 92 %
# Accuracy of  0117 : 95 %
# Accuracy of  0073 : 82 %
# Accuracy of  0016 : 69 %
# Accuracy of  0164 : 95 %
# Accuracy of  0165 : 97 %
# Accuracy of  0036 : 87 %
# Accuracy of  0180 : 71 %
# Accuracy of  0031 : 68 %
# Accuracy of  0193 : 88 %
# Accuracy of  0170 : 90 %
# Accuracy of  0022 : 54 %
# Accuracy of  0118 : 97 %
# Accuracy of  0083 : 67 %
# Accuracy of  0004 : 95 %
# Accuracy of  0148 : 95 %
# Accuracy of  0095 : 95 %
# Accuracy of  0159 : 88 %
# Accuracy of  0078 : 81 %
# Accuracy of  0139 : 97 %
# Accuracy of  0107 : 90 %
# Accuracy of  0071 : 40 %
# Accuracy of  0093 : 100 %
# Accuracy of  0017 : 77 %
