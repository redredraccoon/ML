# %%
import torch
import torch.nn as nn
#from models import VGG16
import torchvision.models as models
from dataset import IMAGE_Dataset
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from pathlib import Path
import copy
import matplotlib.pyplot as plt

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
##REPRODUCIBILITY
torch.manual_seed(123)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
CUDA_DEVICES = 0
DATASET_ROOT = './new/train'
DATASET_ROOT_TEST = './new/test'

# %%
data_transform = transforms.Compose([
		transforms.Resize((224,224)),
		transforms.ToTensor(),
		transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
	])
#print(DATASET_ROOT)
#train_load
train_set = IMAGE_Dataset(Path(DATASET_ROOT), data_transform)
train_data_loader = DataLoader(dataset=train_set, batch_size=32, shuffle=True, num_workers=1)
#test_load
test_set = IMAGE_Dataset(Path(DATASET_ROOT_TEST), data_transform)
test_data_loader = DataLoader(dataset=test_set, batch_size=32, shuffle=True, num_workers=1)

print(train_set.num_classes)
# Out:
# 196

# %%
model = models.resnet101(pretrained=False)

# %%
fc_features = model.fc.in_features
model.fc = nn.Linear(fc_features,196)

model.fc
# Out:
# Linear(in_features=2048, out_features=196, bias=True)

# %%
#model = VGG16(num_classes=train_set.num_classes)
model = model.cuda(CUDA_DEVICES)
model.train()

best_model_params = copy.deepcopy(model.state_dict())
best_acc = 0.0
num_epochs = 20
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model.parameters(), lr=0.001)
#optimizer = torch.optim.Adam(params=model.parameters(), lr=0.001, momentum=0.9)

# %%
train_loss_list = [] 
train_acc_list = [] 
epoch_list = []

test_loss_list = [] 
test_acc_list = [] 
test_epoch_list = []

# %%
for epoch in range(num_epochs):
        print(f'Epoch: {epoch + 1}/{num_epochs}')
        print('-' * len(f'Epoch: {epoch + 1}/{num_epochs}'))

        training_loss = 0.0
        training_corrects = 0

        testing_loss = 0.0
        testing_corrects = 0

        for i, (inputs, labels) in enumerate(train_data_loader):
                inputs = Variable(inputs.cuda(CUDA_DEVICES))
                labels = Variable(labels.cuda(CUDA_DEVICES))			

                optimizer.zero_grad()

                outputs = model(inputs)
                _, preds = torch.max(outputs.data, 1)
                loss = criterion(outputs, labels)

                loss.backward()
                optimizer.step()

                training_loss += loss.item() * inputs.size(0)
                #revise loss.data[0]-->loss.item()
                training_corrects += torch.sum(preds == labels.data)
                #print(f'training_corrects: {training_corrects}')

        training_loss = training_loss / len(train_set)
        training_acc =training_corrects.double() /len(train_set)

        train_loss_list.append(training_loss)
        train_acc_list.append(training_acc)
        epoch_list.append(epoch+1)

        classes = [_dir.name for _dir in Path(DATASET_ROOT_TEST).glob('*')]
        total_correct = 0
        total = 0
        class_correct = list(0. for i in enumerate(classes))
        class_total = list(0. for i in enumerate(classes))
        with torch.no_grad():
            for inputs, labels in test_data_loader:
                    inputs = Variable(inputs.cuda(CUDA_DEVICES))
                    labels = Variable(labels.cuda(CUDA_DEVICES))
                    outputs = model(inputs)
                    _, predicted = torch.max(outputs.data, 1)
                    loss_test = criterion(outputs, labels)
                    # test
                    testing_loss += loss_test.item() * inputs.size(0)
                    testing_corrects += torch.sum(predicted == labels.data)
                    # totoal
                    total += labels.size(0)
                    total_correct += (predicted == labels).sum().item()
                    c = (predicted == labels).squeeze()
                    # batch size
                    for i in range(labels.size(0)):
                        label =labels[i]
                        class_correct[label] += c[i].item()
                        class_total[label] += 1
                
        testing_loss = testing_loss / len(test_set)
        testing_acc =testing_corrects.double() /len(test_set)

        test_loss_list.append(testing_loss)
        test_acc_list.append(testing_acc)
        test_epoch_list.append(epoch+1)


        #print(training_acc.type())
        #print(f'training_corrects: {training_corrects}\tlen(train_set):{len(train_set)}\n')
        print(f'Training loss: {training_loss:.4f}\taccuracy: {training_acc:.4f}\n')
        
        
        if training_acc > best_acc:
                best_acc = training_acc
                best_model_params = copy.deepcopy(model.state_dict())

model.load_state_dict(best_model_params)
# Out:
# Epoch: 1/20
# -----------
# Training loss: 5.3899	accuracy: 0.0055
#
# Epoch: 2/20
# -----------
# Training loss: 5.1935	accuracy: 0.0093
#
# Epoch: 3/20
# -----------
# Training loss: 5.1151	accuracy: 0.0120
#
# Epoch: 4/20
# -----------
# Training loss: 5.0232	accuracy: 0.0151
#
# Epoch: 5/20
# -----------
# Training loss: 4.9126	accuracy: 0.0206
#
# Epoch: 6/20
# -----------
# Training loss: 4.7936	accuracy: 0.0232
#
# Epoch: 7/20
# -----------
# Training loss: 4.6449	accuracy: 0.0336
#
# Epoch: 8/20
# -----------
# Training loss: 4.4380	accuracy: 0.0436
#
# Epoch: 9/20
# -----------
# Training loss: 4.2526	accuracy: 0.0602
#
# Epoch: 10/20
# ------------
# Training loss: 4.0000	accuracy: 0.0878
#
# Epoch: 11/20
# ------------
# Training loss: 3.7056	accuracy: 0.1218
#
# Epoch: 12/20
# ------------
# Training loss: 3.3751	accuracy: 0.1709
#
# Epoch: 13/20
# ------------
# Training loss: 3.0059	accuracy: 0.2377
#
# Epoch: 14/20
# ------------
# Training loss: 2.6603	accuracy: 0.2978
#
# Epoch: 15/20
# ------------
# Training loss: 2.2784	accuracy: 0.3768
#
# Epoch: 16/20
# ------------
# Training loss: 1.8981	accuracy: 0.4672
#
# Epoch: 17/20
# ------------
# Training loss: 1.5525	accuracy: 0.5487
#
# Epoch: 18/20
# ------------
# Training loss: 1.2729	accuracy: 0.6251
#
# Epoch: 19/20
# ------------
# Training loss: 1.0188	accuracy: 0.6893
#
# Epoch: 20/20
# ------------
# Training loss: 0.7762	accuracy: 0.7634

# %%
#model.load_state_dict(best_model_params)
#torch.save(model, f'without,model-{best_acc:.02f}-best_train_acc.pth')

# %%
plt.plot(epoch_list, train_loss_list, label='train')
plt.plot(test_epoch_list, test_loss_list, label='test')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend(['train','test'], loc='upper right')
plt.savefig("loss.png",dpi=250,format="png")
plt.tight_layout()
plt.show()

plt.plot(epoch_list, train_acc_list, label='train')
plt.plot(test_epoch_list, test_acc_list, label='test')
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.legend(['train','test'], loc='upper right')
plt.savefig("accuracy.png",dpi=250,format="png")
plt.tight_layout()
plt.show()

# %%
print('Accuracy on the ALL test images: %d %%'
      % (100 * total_correct / total))

for i, c in enumerate(classes):
    print('Accuracy of %5s : %2d %%' % (
    c, 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy on the ALL test images: 42 %
# Accuracy of  0149 : 71 %
# Accuracy of  0025 : 56 %
# Accuracy of  0174 :  9 %
# Accuracy of  0151 : 34 %
# Accuracy of  0132 : 46 %
# Accuracy of  0010 : 24 %
# Accuracy of  0122 : 55 %
# Accuracy of  0143 : 42 %
# Accuracy of  0026 : 26 %
# Accuracy of  0146 : 88 %
# Accuracy of  0101 : 54 %
# Accuracy of  0075 : 54 %
# Accuracy of  0121 : 70 %
# Accuracy of  0177 : 22 %
# Accuracy of  0130 : 19 %
# Accuracy of  0067 : 28 %
# Accuracy of  0175 : 53 %
# Accuracy of  0154 : 47 %
# Accuracy of  0079 : 45 %
# Accuracy of  0131 : 47 %
# Accuracy of  0059 : 31 %
# Accuracy of  0169 : 39 %
# Accuracy of  0069 : 34 %
# Accuracy of  0072 : 28 %
# Accuracy of  0128 : 53 %
# Accuracy of  0124 :  7 %
# Accuracy of  0009 : 12 %
# Accuracy of  0032 : 24 %
# Accuracy of  0063 : 34 %
# Accuracy of  0171 : 41 %
# Accuracy of  0024 : 20 %
# Accuracy of  0152 : 57 %
# Accuracy of  0189 : 52 %
# Accuracy of  0044 : 45 %
# Accuracy of  0029 : 52 %
# Accuracy of  0127 : 68 %
# Accuracy of  0136 : 20 %
# Accuracy of  0163 : 47 %
# Accuracy of  0061 :  4 %
# Accuracy of  0047 : 34 %
# Accuracy of  0097 : 45 %
# Accuracy of  0092 : 37 %
# Accuracy of  0091 : 33 %
# Accuracy of  0006 : 56 %
# Accuracy of  0065 : 57 %
# Accuracy of  0001 : 45 %
# Accuracy of  0098 : 52 %
# Accuracy of  0051 : 39 %
# Accuracy of  0156 : 46 %
# Accuracy of  0027 : 42 %
# Accuracy of  0106 : 33 %
# Accuracy of  0035 : 41 %
# Accuracy of  0003 : 50 %
# Accuracy of  0108 : 70 %
# Accuracy of  0113 : 61 %
# Accuracy of  0054 : 37 %
# Accuracy of  0062 : 35 %
# Accuracy of  0150 : 52 %
# Accuracy of  0102 : 66 %
# Accuracy of  0076 : 62 %
# Accuracy of  0167 : 37 %
# Accuracy of  0042 : 11 %
# Accuracy of  0033 : 52 %
# Accuracy of  0157 : 66 %
# Accuracy of  0145 :  9 %
# Accuracy of  0048 : 45 %
# Accuracy of  0176 : 50 %
# Accuracy of  0186 : 30 %
# Accuracy of  0135 : 62 %
# Accuracy of  0060 : 63 %
# Accuracy of  0052 : 39 %
# Accuracy of  0160 : 25 %
# Accuracy of  0195 : 39 %
# Accuracy of  0058 : 40 %
# Accuracy of  0066 : 29 %
# Accuracy of  0103 : 69 %
# Accuracy of  0181 : 50 %
# Accuracy of  0056 : 19 %
# Accuracy of  0085 : 75 %
# Accuracy of  0050 : 64 %
# Accuracy of  0158 : 13 %
# Accuracy of  0015 : 60 %
# Accuracy of  0184 : 17 %
# Accuracy of  0142 : 56 %
# Accuracy of  0119 : 63 %
# Accuracy of  0096 : 28 %
# Accuracy of  0190 : 39 %
# Accuracy of  0081 : 60 %
# Accuracy of  0088 : 66 %
# Accuracy of  0144 : 28 %
# Accuracy of  0188 : 53 %
# Accuracy of  0178 : 21 %
# Accuracy of  0087 :  9 %
# Accuracy of  0074 : 23 %
# Accuracy of  0012 : 27 %
# Accuracy of  0007 : 46 %
# Accuracy of  0161 : 31 %
# Accuracy of  0086 : 42 %
# Accuracy of  0166 : 53 %
# Accuracy of  0057 : 40 %
# Accuracy of  0173 : 32 %
# Accuracy of  0040 : 51 %
# Accuracy of  0168 : 80 %
# Accuracy of  0137 : 27 %
# Accuracy of  0070 : 14 %
# Accuracy of  0109 : 54 %
# Accuracy of  0021 : 35 %
# Accuracy of  0043 : 39 %
# Accuracy of  0034 :  4 %
# Accuracy of  0162 : 53 %
# Accuracy of  0120 : 64 %
# Accuracy of  0039 : 41 %
# Accuracy of  0104 :  9 %
# Accuracy of  0133 : 26 %
# Accuracy of  0045 : 37 %
# Accuracy of  0153 : 56 %
# Accuracy of  0002 : 62 %
# Accuracy of  0134 : 58 %
# Accuracy of  0089 : 35 %
# Accuracy of  0037 : 44 %
# Accuracy of  0183 : 30 %
# Accuracy of  0116 : 35 %
# Accuracy of  0138 : 58 %
# Accuracy of  0147 : 77 %
# Accuracy of  0019 :  0 %
# Accuracy of  0155 : 19 %
# Accuracy of  0020 : 23 %
# Accuracy of  0023 : 30 %
# Accuracy of  0068 : 42 %
# Accuracy of  0011 : 86 %
# Accuracy of  0041 : 40 %
# Accuracy of  0140 : 45 %
# Accuracy of  0141 : 52 %
# Accuracy of  0090 : 39 %
# Accuracy of  0187 : 46 %
# Accuracy of  0055 : 10 %
# Accuracy of  0105 : 34 %
# Accuracy of  0064 : 41 %
# Accuracy of  0005 : 32 %
# Accuracy of  0182 : 56 %
# Accuracy of  0172 : 46 %
# Accuracy of  0100 : 45 %
# Accuracy of  0110 : 79 %
# Accuracy of  0080 : 30 %
# Accuracy of  0094 : 81 %
# Accuracy of  0030 : 39 %
# Accuracy of  0185 : 26 %
# Accuracy of  0053 : 52 %
# Accuracy of  0114 : 53 %
# Accuracy of  0008 : 37 %
# Accuracy of  0049 : 72 %
# Accuracy of  0191 : 58 %
# Accuracy of  0111 : 26 %
# Accuracy of  0179 : 40 %
# Accuracy of  0192 : 38 %
# Accuracy of  0126 : 38 %
# Accuracy of  0038 : 37 %
# Accuracy of  0082 : 17 %
# Accuracy of  0028 : 63 %
# Accuracy of  0013 : 68 %
# Accuracy of  0194 : 48 %
# Accuracy of  0129 : 28 %
# Accuracy of  0014 : 40 %
# Accuracy of  0099 : 59 %
# Accuracy of  0115 : 64 %
# Accuracy of  0123 : 62 %
# Accuracy of  0112 : 48 %
# Accuracy of  0077 : 32 %
# Accuracy of  0084 : 19 %
# Accuracy of  0196 : 55 %
# Accuracy of  0046 : 46 %
# Accuracy of  0125 : 79 %
# Accuracy of  0018 : 45 %
# Accuracy of  0117 : 52 %
# Accuracy of  0073 : 33 %
# Accuracy of  0016 : 16 %
# Accuracy of  0164 :  4 %
# Accuracy of  0165 : 52 %
# Accuracy of  0036 : 21 %
# Accuracy of  0180 :  9 %
# Accuracy of  0031 : 40 %
# Accuracy of  0193 : 42 %
# Accuracy of  0170 : 29 %
# Accuracy of  0022 :  2 %
# Accuracy of  0118 : 46 %
# Accuracy of  0083 : 20 %
# Accuracy of  0004 : 38 %
# Accuracy of  0148 : 46 %
# Accuracy of  0095 : 55 %
# Accuracy of  0159 : 38 %
# Accuracy of  0078 : 40 %
# Accuracy of  0139 : 61 %
# Accuracy of  0107 : 43 %
# Accuracy of  0071 : 17 %
# Accuracy of  0093 : 61 %
# Accuracy of  0017 : 40 %
